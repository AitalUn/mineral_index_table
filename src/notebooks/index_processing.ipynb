# %% [markdown]
# # **Скачивание статей**

# %%
import pandas as pd
import json
import re
import os
from pathlib import Path


index_path = Path(os.getcwd()) / "index_data.json"
satellite_path = Path(os.getcwd()).parent.parent / "data" / "sat_data" / "satellite_spectrums.json"

with open(index_path, 'r', encoding='utf-8') as file:
    index_data = json.load(file)

with open(satellite_path, 'r', encoding='utf8') as file:
    bands_data = json.load(file)

# %%
formulas = [d['formula'] for d in index_data]

# %%
ALIASES = {
    "BLUE": (450, 520),
    "B":    (450, 520),
    "GREEN": (520, 600),
    "G":     (520, 600),
    "RED": (630, 690),
    "R":   (630, 690),
    "NIR": (760, 1400),
    "SWIR": (1400, 3000),
    "SWIR1": (1550, 1750),
    "SWIR2": (2080, 2350),
    "MIR":
    "rededge":
    "RVI": 
}


def alias_to_range(name: str):
    """Return alias numeric center value or (lo,hi)."""
    if name not in ALIASES:
        return None
    lo, hi = ALIASES[name]
    return (lo + hi) / 2   # можно вернуть диапазон полностью, если хочешь


def preprocess_aliases(formula: str) -> str:
    """Replace spectral alias names (RED, NIR, etc.) with numeric values."""
    for name in ALIASES:
        pattern = r"\b" + name + r"\b"
        value = alias_to_range(name)
        formula = re.sub(pattern, str(value), formula)
    return formula

# %%
for index in index_data:
    index["formula"] = preprocess_aliases(index["formula"])

# %%
import re
import sympy as sp
from sympy import sympify, simplify

def wavelength_to_band(wl_min, wl_max, bands):
    for bname, (bmin, bmax) in bands.items():
        # intersection check
        if wl_min >= bmin and wl_max <= bmax:
            return bname
    return "nan"


def convert_formula(formula, sat="landsat8"):
    f = formula

    # --- Replace ranges [700:710] ---
    def repl_range(m):
        lo = int(m.group(1))
        hi = int(m.group(2))
        b = wavelength_to_band(lo, hi, sat)
        return b

    f = re.sub(r"\[(\d+):(\d+)\]", repl_range, f)

    # --- Replace single [700] ---
    def repl_single(m):
        wl = int(m.group(1))
        b = wavelength_to_band(wl, wl, sat)
        return b

    f = re.sub(r"\[(\d+)\]", repl_single, f)

    # --- Replace "700nm" ---
    def repl_nm(m):
        wl = int(m.group(1))
        b = wavelength_to_band(wl, wl, sat)
        return b

    f = re.sub(r"(\d+)nm", repl_nm, f)

    # If variables like RED, BLUE appear — leave as is.

    # --- Simplify with sympy ---
    try:
        expr = sympify(f)
        f = str(simplify(expr))
    except Exception:
        pass

    return f

for formula in formulas:
    print(formula, " → ", convert_formula(formula, bands_data['landsat7']))
# Out:
# (734nm - 747nm)/(715nm - 720nm)  →  nan
# 735nm/[700:710]  →  1
# [8475:8825]**2/([8125:8475]*[8925:9275])  →  nan
# [700]*([670]*(([700]-[550])/[150]) + [670] + [550] - (([700]-[550])/[150]*[550]) )/([670]*(((([700]-[550])/[150]))**2 + 1)**0.5)  →  nan
# (1094nm - 1205nm)/(1094nm + 1205nm)  →  0
# 900nm*(680nm + 800nm)/(970nm*(-680nm + 800nm))  →  nan
# 0.666666666666667*700nm*(0.2*550nm - 670nm + 0.8*700nm)*sqrt(5*sqrt(670nm) - 6*800nm + (2*800nm + 1)**2 + 0.5)/(670nm*(1.3*550nm - 2.5*670nm + 1.2*800nm))  →  B8*(0.133333333333333*B2 - 0.666666666666667*B3 + 0.533333333333333*B8)*sqrt(5*sqrt(B3) + 4*B4**2 - 2*B4 + 1.5)/(B3*(1.3*B2 - 2.5*B3 + 1.2*B4))
# (-BLUE - GREEN + NIR - RED)/(BLUE + GREEN + NIR + RED)  →  (-BLUE - GREEN + NIR - RED)/(BLUE + GREEN + NIR + RED)
# [2145:2185]/[2185:2225]  →  1
# (531nm - 570nm)/(531nm + 570nm)  →  0
# Averagereflectancebetween750nmand850nm  →  AveragereflectancebetweenB8andB4
# 2250nm  →  B6
# (-550nm + 800nm)/(550nm + 800nm)  →  (-B2 + B4)/(B2 + B4)
# 0  →  0
# NIR - RED*a  →  NIR - RED*a
# 703nm  →  B8
# (NIR - RED + y*(-BLUE + RED))/(NIR + RED - y*(-BLUE + RED))  →  (NIR - RED - y*(BLUE - RED))/(NIR + RED + y*(BLUE - RED))
# [2145:2185]/[2185:2225]  →  1
# 683nm/510nm  →  B3/B1
# [2185:2225]/[2295:2365]  →  nan
# (-1/700nm + 1/550nm)/NIR  →  (-B2 + B8)/(B2*B8*NIR)
# 700nm*(0.2*550nm - 670nm + 0.8*700nm)/670nm  →  B8*(0.2*B2 - B3 + 0.8*B8)/B3
# 2080nm  →  nan
# (-680nm + 800nm)/(680nm + 800nm)  →  (-B3 + B4)/(B3 + B4)
# (-670nm + 790nm)/(670nm + 790nm)  →  (-B3 + B4)/(B3 + B4)
# 750nm/555nm  →  B8/B2
# ([1600:1700] - [2145:2185])/([1600:1700] + [2145:2185])  →  (B5 - B6)/(B5 + B6)
# (-1510nm + 800nm)*(0.16 + 1)/(1510nm + 800nm + 0.16)  →  nan
# -[1400:3000]/[3000] + [3000]*[780]/[640:760] + [1400]  →  nan
# 635nm  →  B3
# 930nm  →  nan
# (-1600nm + 820nm)/(1600nm + 820nm)  →  (B4 - B5)/(B4 + B5)
# 754nm/704nm  →  1
# 860nm/(550nm*708nm)  →  B4/(B2*B8)
# 40.0*550nm - 100.0*670nm + 60.0*750nm  →  40.0*B2 - 100.0*B3 + 60.0*B8
# (log([1754]) - log([1680]))/(log([1754]) + log([1680]))  →  nan
# 6*750nm*(-550nm + 750nm)*(-705nm + 750nm)/705nm  →  0
# Can't parse  →  Can't parse
# ([2185:2225] + [2360:2430])/[2295:2365]  →  nan
# [700:1300]/[1570:1780]  →  nan
# (-710nm + 750nm)/(710nm + 750nm)  →  0
# 1450nm  →  nan
# (-BLUE + 0.1*NIR)/(BLUE + 0.1*NIR)  →  (-BLUE + 0.1*NIR)/(BLUE + 0.1*NIR)
# 675nm*800nm*r675/(650nm*r650*r800)  →  B4*r675/(r650*r800)
# R/(G + NIR + R)  →  R/(G + NIR + R)
# Can't parse  →  Can't parse
# [1600:1700]/[2145:2185]  →  B5/B6
# ([1600:1700] - [760:860])/([1600:1700] + [760:860])  →  (B5 - B8)/(B5 + B8)
# 695nm/760nm  →  1
# ([1600:1700] + [2185:2225])/[2145:2185]  →  (B5 + B6)/B6
# [10250:10950]/[10950:11650]  →  nan
# -1 + NIR/GREEN  →  (-GREEN + NIR)/GREEN
# 640nm  →  B3
# (547nm + 802nm)/(1657nm + 682nm)  →  (B2 + B4)/(B3 + B5)
# 1058nm/1148nm  →  1
# 750nm/700nm  →  1
# 2100nm  →  B6
# (-710nm + 780nm)/(-680nm + 780nm)  →  (-B4 + B8)/(B3 - B4)
# 2240nm  →  B6
# (0.1*NIR - RED)/(0.1*NIR + RED)  →  (0.1*NIR - RED)/(0.1*NIR + RED)
# (-BLUE + RED)/RED  →  (-BLUE + RED)/RED
# 800nm/650nm  →  B4/B3
# 2130nm  →  B6
# 1690nm  →  B5
# 1/700nm  →  1/B8
# 660nm  →  B3
# (-531nm + 570nm)/(531nm + 570nm)  →  0
# (-720nm + 790nm)/(720nm + 790nm)  →  (B4 - B8)/(B4 + B8)
# 680nm*700nm*r680/(635nm*r635*r700)  →  B8*r680/(r635*r700)
# 1.16*(-705nm + 750nm)/(705nm + 750nm + 0.16)  →  0
# [708:716]/[676:685]  →  B8/B3
# (-[676:685] + [708:716])/([676:685] + [708:716])  →  (-B3 + B8)/(B3 + B8)
# 1.5*(1.3*550nm - 2.5*670nm + 1.2*800nm)/sqrt(5*sqrt(670nm) - 6*800nm + (2*800nm + 1)**2 + 0.5)  →  1.0*(1.95*B2 - 3.75*B3 + 1.8*B4)/sqrt(5*sqrt(B3) + 4*B4**2 - 2*B4 + 1.5)
# [10250:10950]/[8125:8475]  →  nan
# 1.17*(NIR - RED)/(NIR + RED) - 0.18  →  (0.99*NIR - 1.35*RED)/(NIR + RED)
# (-GREEN + NIR)/(GREEN + NIR)  →  (-GREEN + NIR)/(GREEN + NIR)
# (528nm - 567nm)/(528nm + 567nm)  →  (-B2 + B8)/(B2 + B8)
# 718nm/2 - 733nm + 748nm/2  →  0
# 710nm/760nm  →  1
# -3*670nm + 3*700nm - 0.6*700nm*(-550nm + 700nm)/670nm  →  (3*B3*(-B3 + B8) + 0.6*B8*(B2 - B8))/B3
# (-BLUE + NIR)/(BLUE + NIR)  →  (-BLUE + NIR)/(BLUE + NIR)
# 990nm  →  nan
# 740  →  740
# 1960nm  →  nan
# 700 + 40*(670nm/2 - 700nm + 780nm/2)/(-700nm + 740nm)  →  zoo*(B3 + B4 - 2*B8) + 700
# [630:690]/[520:600]  →  B3/B8
# 1200nm  →  B7
# (1148nm - 807nm*a + b)/(a**2 + 1)**0.5  →  (-B4*a + B7 + b)/(a**2 + 1)**0.5
# NIR/(RED + SWIR)  →  NIR/(RED + SWIR)
# 680nm*800nm*r680/(635nm*r635*r800)  →  B4*r680/(r635*r800)
# (-500nm + 678nm)/750nm  →  (-B1 + B3)/B8
# (-GREEN + NIR - RED)/(GREEN + NIR + RED)  →  (-GREEN + NIR - RED)/(GREEN + NIR + RED)
# 1900nm  →  nan
# 1120nm  →  B7
# 560nm/658nm  →  B2/B3
# 690nm/740nm  →  B3/B8
# 970nm/902nm  →  nan
# -0.48*530nm - 1.0*670nm + 1.48*800nm  →  -0.48*B2 - 1.0*B3 + 1.48*B4
# 2060nm  →  nan
# 800nm*r470/(470nm*r800)  →  B4*r470/(B1*r800)
# SWIRI/NIR  →  SWIRI/NIR
# B*(A - B*R + NIR)/(B*(-A + NIR) + RED + X*(B**2 + 1))  →  B*(A - B*R + NIR)/(-B*(A - NIR) + RED + X*(B**2 + 1))
# (-550nm + 750nm)/(550nm + 750nm)  →  (-B2 + B8)/(B2 + B8)
# 1400nm  →  nan
# -G + NIR  →  -G + NIR
# Can't parse  →  Can't parse
# 750nm*(0.2*550nm - 705nm + 0.8*750nm)/705  →  B8*(0.000283687943262411*B2 - 0.000283687943262411*B8)
# 801nm/550nm  →  B4/B2
# Can't parse  →  Can't parse
# (-445nm + 800nm)/(-680nm + 800nm)  →  nan
# 550nm  →  B2
# Can't parse  →  Can't parse
# 1660nm/550nm  →  B5/B2
# MIR/NIR  →  MIR/NIR
# 715nm/705nm  →  1
# 430nm/680nm  →  nan
# RED/BLUE  →  RED/BLUE
# 1  →  1
# [8475:8825]**2*[8925:9275]/[8125:8475]  →  nan
# (-710nm + 850nm)/(-680nm + 850nm)  →  (-B4 + B8)/(B3 - B4)
# [1600:1700]/[630:690]  →  B5/B3
# 1420nm  →  nan
# -680nm + 800nm  →  -B3 + B4
# ([2235:2365] + [2360:2430])/[2295:2365]  →  nan
# ([2145:2185] + [2235:2365])/[2185:2225]  →  nan
# (-BLUE - GREEN + NIR)/(BLUE + GREEN + NIR)  →  (-BLUE - GREEN + NIR)/(BLUE + GREEN + NIR)
# Can't parse  →  Can't parse
# [710:720]/[700:710]  →  1
# 450nm/690nm  →  B1/B3
# NIR/(G + NIR + R)  →  NIR/(G + NIR + R)
# (MIR - NIR)/(MIR + NIR)  →  (MIR - NIR)/(MIR + NIR)
# SWIRI/SWIRII  →  SWIRI/SWIRII
# 550nm/680nm  →  B2/B3
# Can't parse  →  Can't parse
# (BLUE + 2*GREEN - RED)/(BLUE + 2*GREEN + RED)  →  (BLUE + 2*GREEN - RED)/(BLUE + 2*GREEN + RED)
# (NIR - [690:710])/(NIR + [690:710])  →  (-B8 + NIR)/(B8 + NIR)
# 800nm/675nm  →  B4/B3
# (-[710] + [850])/([680] + [850])  →  (B4 - B8)/(B3 + B4)
# ([770:780] + [784:790])/([655:665] + [676:685])  →  (B4 + B8)/(2*B3)
# [2145:2185]/[760:860] + [520:600]/[630:690]  →  B6/B8 + B8/B3
# 450nm/550nm  →  B1/B2
# (-705nm + 750nm)/(705nm + 750nm)  →  0
# -1.2*550nm + 1.2*700nm - 1.5*sqrt(700nm/670nm)*(-550nm + 670nm)  →  -1.2*B2 + 1.2*B8 + 1.5*sqrt(B8/B3)*(B2 - B3)
# Can't parse  →  Can't parse
# 900nm*(705nm + 750nm)/(750nmâ705nm*970nm)  →  nan
# n*(1 - 0.25*n) - (RED - 0.125)/(1 - RED)  →  (RED - n*(RED - 1)*(0.25*n - 1) - 0.125)/(RED - 1)
# 2320nm  →  B6
# 695nm/670nm  →  B8/B3
# (NIR - ar + b)/sqrt(a**2 + 1)  →  (NIR - ar + b)/sqrt(a**2 + 1)
# (-1241nm + 857nm)/(1241nm + 857nm)  →  (B4 - B7)/(B4 + B7)
# [10250:10950]/[8925:9275]  →  nan
# 2310nm  →  B6
# 1.56*550nm - 3.0*670nm + 1.44*800nm  →  1.56*B2 - 3.0*B3 + 1.44*B4
# (-RED + rededge)/(RED + rededge)  →  (-RED + rededge)/(RED + rededge)
# 675nm/700nm  →  B3/B8
# 1.56*550nm - 3.0*670nm + 1.44*800nm  →  1.56*B2 - 3.0*B3 + 1.44*B4
# 1820nm  →  nan
# 50.0*2030nm - 100*2100nm + 50.0*2210nm  →  nan
# 750nm/550nm  →  B8/B2
# 750nm/710nm  →  1
# (734nm - 747nm)/(715nm + 726nm)  →  0
# NIR - sqrt(-8*NIR + 8*RED + (2*NIR + 1)**2)/2 + 1/2  →  NIR - sqrt(-8*NIR + 8*RED + (2*NIR + 1)**2)/2 + 1/2
# (-445nm + 750nm)/(-445nm + 705nm)  →  nan
# (RVI - 1)/(RVI + 1)  →  (RVI - 1)/(RVI + 1)
# [690:720]/[760:800]  →  1
# 833nm/1649nm  →  B4/B5
# (-670nm + 800nm)*(Y + 1)/(670nm + 800nm + Y)  →  -(B3 - B4)*(Y + 1)/(B3 + B4 + Y)
# 554nm/677nm  →  B2/B3
# MIR/RED  →  MIR/RED
# (NIR + Red)*(NIR - rededge)/((NIR - Red)*(NIR + rededge))  →  (NIR + Red)*(NIR - rededge)/((NIR - Red)*(NIR + rededge))
# (NIR - SWIR)/(NIR + SWIR)  →  (NIR - SWIR)/(NIR + SWIR)
# MIR/SWIR  →  MIR/SWIR
# (-675nm + 800nm)/(675nm + 800nm)  →  (-B3 + B4)/(B3 + B4)
# 970nm/900nm  →  nan
# Can't parse  →  Can't parse
# 1490nm  →  nan
# 801nm/670nm  →  B4/B3
# [2145:2185]/[760:860] + [520:600]/[630:690]  →  B6/B8 + B8/B3
# NIR/rededge - 1  →  (NIR - rededge)/rededge
# -550nm + 800nm  →  -B2 + B4
# 1980nm  →  nan
# 742  →  742
# 100*(NDVIj - NDVImin)/(NDVImax - NDVImin)  →  100*(NDVIj - NDVImin)/(NDVImax - NDVImin)
# (-DW + FW)/(-DW + TW)  →  (DW - FW)/(DW - TW)
# ([2185:2225] + [2295:2365])/[2235:2365]  →  nan
# 690nm/735nm  →  B3/B8
# (-430nm + 680nm)/(430nm + 680nm)  →  nan
# 800nm*r500/(500nm*r800)  →  B4*r500/(B1*r800)
# (-G + NIR)*(L + 1)/(G + L + NIR)  →  -(G - NIR)*(L + 1)/(G + L + NIR)
# 2270nm  →  B6
# -0.5*2100nm/(0.56*2100nm + NIR) + NIR  →  (-0.5*B6 + NIR*(0.56*B6 + NIR))/(0.56*B6 + NIR)
# (-G + R)/(G + R)  →  (-G + R)/(G + R)
# Can't parse  →  Can't parse
# Can't parse  →  Can't parse
# 1530nm  →  nan
# 470nm  →  B1
# [8475:8825]/[8925:9275]  →  nan
# (-680nm + 800nm)/(-2*445nm + 680nm + 800nm)  →  nan
# 950nm/900nm  →  nan
# (-1240nm + 860nm)/(1240nm + 860nm)  →  (B4 - B7)/(B4 + B7)
# 0.0327868852459016*B + 0.0327868852459016*G + 0.0327868852459016*R  →  0.0327868852459016*B + 0.0327868852459016*G + 0.0327868852459016*R
# 860nm/1240nm  →  B4/B7
# (NIR - [540:570])/(NIR + [540:570])  →  (-B2 + NIR)/(B2 + NIR)
# (B - G + 2*R)/(-B + G)  →  (-B + G - 2*R)/(B - G)
# (GREEN - RED)/(GREEN + RED)  →  (GREEN - RED)/(GREEN + RED)
# 970nm  →  nan
# 2300nm  →  B6
# [2235:2365]/[2185:2225]  →  nan
# (NIR - b)/(RED*a)  →  (NIR - b)/(RED*a)
# 695nm/420nm  →  nan
# 800nm/500nm  →  B4/B1
# -0.7112*[1550:1750] + 0.4572*[2080:2350] + 0.1509*[450:520] + 0.1973*[520:600] + 0.3279*[630:690] + 0.3406*[760:900]  →  nan
# 1940nm  →  nan
# (688nm + 710nm)/697nm**2  →  (B3 + B8)/B8**2
# ([2185:2225] + [2360:2430])/([2235:2365] + [2295:2365])  →  nan
# 2340nm  →  B6
# 750nm*(0.2*550nm - 710nm + 0.8*750nm)/710  →  B8*(0.00028169014084507*B2 - 0.00028169014084507*B8)
# 2*[1180:1220]/([1090:1110] + [1265:1285])  →  nan
# (-445nm + 800nm)/(-445nm + 680nm)  →  nan
# 1.0*800nm - 0.5*sqrt(8*670nm - 8*800nm + (2*800nm + 1)**2) + 0.5  →  1.0*B4 - 0.5*sqrt(8*B3 - 8*B4 + (2*B4 + 1)**2) + 0.5
# (-BLUE + NIR - RED)/(BLUE + NIR + RED)  →  (-BLUE + NIR - RED)/(BLUE + NIR + RED)
# 700nm*sqrt((670nm + 670*a + b)**2)/(670nm*(a**2 + 1)**0.5)  →  B8*sqrt((B3 + 670*a + b)**2)/(B3*(a**2 + 1)**0.5)
# (-470nm + 800nm)/(470nm + 800nm)  →  (-B1 + B4)/(B1 + B4)
# 1600nm/820nm  →  B5/B4
# -0.66*1600nm/(0.66*1600nm + NIR) + NIR  →  (-0.66*B5 + NIR*(0.66*B5 + NIR))/(0.66*B5 + NIR)
# 430nm/680nm  →  nan
# Can't parse  →  Can't parse
# -1 + 750nm/710nm  →  0
# 440nm/690nm  →  nan
# 605nm/760nm  →  B2/B8
# 740  →  740
# sqrt(5)*sqrt(NDVI)  →  sqrt(5)*sqrt(NDVI)
# 760nm*r500/(500nm*r760)  →  B8*r500/(B1*r760)
# 720nm  →  B8
# (-MIR + NIR)/(MIR + NIR)  →  (-MIR + NIR)/(MIR + NIR)
# (-705nm + 750nm)/(-2*445nm + 705nm + 750nm)  →  nan
# 1540nm  →  nan
# 2260nm−1490nm/(1490nm + 2260nm)  →  nan
# NIR/G  →  NIR/G
# (-[620:680] + [700:710])/([620:680] + [700:710])  →  0
# 895nm/972nm  →  nan
# 800nm/680nm  →  B4/B3
# (-505nm + 800nm)/(-690nm + 800nm)  →  (B1 - B4)/(B3 - B4)
# 700nm/670nm  →  B8/B3
# NIR/[700:715]  →  NIR/B8
# (-500nm + 800nm)/(500nm + 800nm)  →  (-B1 + B4)/(B1 + B4)
# 1780nm  →  nan
# 810nm/560nm  →  B4/B2
# [734:747]/[715:726]  →  1
# 800nm/670nm  →  B4/B3
# 1580nm  →  B5
# Can't parse  →  Can't parse
# 2160nm−1540nm/(1540nm + 2160nm)  →  nan
# 1020nm  →  nan
# (-G + NIR)/(G + NIR + Y)  →  (-G + NIR)/(G + NIR + Y)
# NIR/RED  →  NIR/RED
# 1725nm - 970nm  →  nan
# 1250nm/1050nm  →  1
# 800nm/470nm  →  B4/B1
# (-1640nm + 860nm)/(1640nm + 860nm)  →  (B4 - B5)/(B4 + B5)
# NIR*(NDVI + 1)/(2*(NIR + RED))  →  NIR*(NDVI + 1)/(2*(NIR + RED))
# (1094nm - 893nm)/(1094nm + 893nm)  →  (-B4 + B7)/(B4 + B7)
# 1040nm  →  B7
# NIR/rededge  →  NIR/rededge
# (-A + C)/(-A + B)  →  (A - C)/(A - B)
# (-[655:665] - [676:685] + [770:780] + [784:790])/([655:665] + [676:685] + [770:780] + [784:790])  →  (-2*B3 + B4 + B8)/(2*B3 + B4 + B8)
# (-709nm + 754nm)/(-681nm + 709nm)  →  0
# 672nm/(550nm*708nm)  →  B3/(B2*B8)
# [8475:8825]/[8125:8475]  →  nan
# 550nm/800nm  →  B2/B4
# 675nm*700nm*r675/(650nm*r650*r700)  →  B8*r675/(r650*r700)
# 2000nm  →  nan
# 800nm/550nm  →  B4/B2
# 740nm/720nm  →  1
# (-670nm + 800nm)*(L + 1)/(670nm + 800nm + L)  →  -(B3 - B4)*(L + 1)/(B3 + B4 + L)
# 700nm*(-1510nm + 0.2*550nm + 0.8*700nm)/1510nm  →  nan
# 910nm  →  nan
# (415nm - 435nm)/(415nm + 435nm)  →  nan
# (-658nm + 833nm)/sqrt(658nm + 833nm)  →  (-B3 + B4)/sqrt(B3 + B4)
# [1600:1700]/[2145:2185]  →  B5/B6
# [2145:2185]/[1600:1700]  →  B6/B5
# (-1650nm + 850nm)/(1650nm + 850nm)  →  (B4 - B5)/(B4 + B5)
# G/(G + NIR + R)  →  G/(G + NIR + R)
# 0.5082*[1150:1750] + 0.1863*[2080:2350] + 0.3037*[450:520] + 0.2793*[520:600] + 0.4743*[630:690] + 0.5585*[760:900]  →  nan
# rededge/RED  →  rededge/RED
# 675nm/(650nm*700nm)  →  1/B8
# NIR*RED/GREEN**2  →  NIR*RED/GREEN**2
# a*(NIR - RED*a + b)/(NIR*a + RED + X*(a**2 + 1) - a*b)  →  a*(NIR - RED*a + b)/(NIR*a + RED + X*(a**2 + 1) - a*b)
# (L + 1)*(800nm - Rr + y)/(800nm + L + Rr - y)  →  (L + 1)*(B4 - Rr + y)/(B4 + L + Rr - y)
# 672nm/550nm  →  B3/B2
# 925nm−710nm/(710nm + 925nm)  →  nan
# (-550nm + 800nm)/(1660nm + 680nm)  →  (-B2 + B4)/(B3 + B5)
# 800nm/1660nm  →  B4/B5
# 2*[960:990]/([1090:1110] + [920:940])  →  nan
# [8925:9275]/[10250:10950]  →  nan
# (NIR*a - RED*a + b)/(NIR*a + RED - a*b)  →  (NIR*a - RED*a + b)/(NIR*a + RED - a*b)
# [2145:2185]*[2235:2365]/[2185:2225]**2  →  nan
# [10950:11650]/[8925:9275]  →  nan
# (-650nm + 800nm)/(650nm + 800nm)  →  (-B3 + B4)/(B3 + B4)
# 675nm*r700/(700nm*r675)  →  B3*r700/(B8*r675)
# sqrt(5)*sqrt(NDVI)  →  sqrt(5)*sqrt(NDVI)
# 430nm  →  nan
# 2180nm  →  B6
# 680nm*r700/(700nm*r680)  →  B3*r700/(B8*r680)
# 2280nm  →  B6
# [1600:1700]/[760:860]  →  B5/B8
# (-670nm + 800nm)/(670nm + 800nm)**0.5  →  (-B3 + B4)/(B3 + B4)**0.5
# 1193nm/1126nm  →  1
# 2.5*(NIR - RED)/(-7.5*BLUE + NIR + 6*RED + 1)  →  2.5*(NIR - RED)/(-7.5*BLUE + NIR + 6*RED + 1)
# (NIR - rededge)/(NIR + rededge)  →  (NIR - rededge)/(NIR + rededge)
# 1.5*(1.3*550nm - 2.5*670nm + 1.2*800nm)/sqrt(5*sqrt(670nm) - 6*800nm + (2*800nm + 1)**2 + 0.5)  →  1.0*(1.95*B2 - 3.75*B3 + 1.8*B4)/sqrt(5*sqrt(B3) + 4*B4**2 - 2*B4 + 1.5)
# 460nm  →  B1
# 1  →  1
# 672nm - 701nm - 720nm + 749nm  →  B3 - B8
# (-670nm + 800nm)/sqrt(670nm + 800nm)  →  (-B3 + B4)/sqrt(B3 + B4)
# 706nm/750nm  →  1
# (-470nm + 800nm)/(-680nm + 800nm)  →  (B1 - B4)/(B3 - B4)
# 0.084*[1550:1750] - 0.18*[2080:2350] - 0.2848*[450:520] - 0.2435*[520:600] + 0.5436*[630:690] + 0.7243*[760:900]  →  nan
# Can't parse  →  Can't parse
# 2350nm  →  B6
# 800nm/600nm  →  B4/B2
# (NIR - RED)/(NIR + RED)  →  (NIR - RED)/(NIR + RED)
# 1510nm  →  nan
# [2235:2365]/[2145:2185]  →  nan
# 800nm/635nm  →  B4/B3
# -1/700nm + 1/550nm  →  (-B2 + B8)/(B2*B8)
# 1660nm/680nm  →  B5/B3
# 680nm  →  B3
# Can't parse  →  Can't parse
# [540:560]/[760:800]  →  B2/B8
# (-550nm + 780nm)/(550nm + 780nm)  →  (-B2 + B4)/(B2 + B4)

# %%
for index in index_data:
    sat_formulas = []
    for sat in bands_data:
        sat_formulas.append({sat: convert_formula(index['formula'], bands_data[sat])})
    index['satellite_formulas'] = sat_formulas

# %%
import pandas as pd

df = pd.DataFrame(index_data)
def merge_sat_formulas(lst):
    merged = {}
    for d in lst:
        merged.update(d)
    return merged

sat_df = df['satellite_formulas'].apply(merge_sat_formulas).apply(pd.Series)

# --- Соединяем с остальными колонками ---
df = df.drop(columns=['satellite_formulas']).join(sat_df)

# --- Результат ---
df.to_excel("index_table_v1.xlsx")

# %%
index_data
# Out:
# [{'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=365',
#   'name': 'Modified Normalized Difference 734/747/715/720\r',
#   'abbreviation': 'MD734/747/715/72\r',
#   'formula': '(734nm - 747nm)/(715nm - 720nm)',
#   'references': [{'article_name': 'Gitelson, Anatoly A.; Merzlyak, Mark N.; Lichtenthaler, Hartmut K. - Detection of Red Edge Position and Chlorophyll Content by Reflectance Measurements Near 700 nm\n',
#     'article_link': '10.1016/s0176-1617(96)80285-9',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0176161796802859'},
#    {'article_name': 'le Maire, G.; Francois, C.; Dufrene, E. - Towards universal broad leaf chlorophyll indices using PROSPECT simulated database and hyperspectral reflectance measurements\n',
#     'article_link': '10.1016/j.rse.2003.09.004',
#     'article_doi': ''},
#    {'article_name': 'Moss, D.M.; Rock, B.N. - Analysis of red edge spectral characteristics and total chlorophyll values for red spruce (Picea rubens) branch segments from Mt. Moosilauke, N.H., U.S.A. 11th\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Vogelmann, J.E.; Rock, B.N.; Moss, D.M.  - Red Edge Spectral Measurements from Sugar Maple Leaves\n',
#     'article_link': '10.1080/01431169308953986',
#     'article_doi': 'http://dx.doi.org/10.1080/01431169308953986'},
#    {'article_name': 'Zarco-Tejada P.J.; Sepulcre-CantÃ³, G. - REMOTE SENSING OF VEGETATION BIOPHYSICAL PARAMETERS FOR DETECTING STRESS CONDITION AND LAND COVER CHANGES\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Zarco-Tejada, P. J.; Miller, J. R.; Noland, T. L.; Mohammed, G. H.; Sampson, P. H.  - Scaling-up and model inversion methods with narrow-band optical indices for chlorophyll content estimation in closed forest canopies with hyperspectral data\n',
#     'article_link': '',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': 'nan'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': '(VNIR_58 - VNIR_60)/(VNIR_55 - VNIR_56)'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=409',
#   'name': 'Simple Ratio 735/710\r',
#   'abbreviation': 'SR735/710\r',
#   'formula': '735nm/[700:710]',
#   'references': [{'article_name': 'Gitelson, Anatoly A.; Buschmann, Claus; Lichtenthaler, Hartmut K. - The Chlorophyll Fluorescence Ratio F735/F700 as an Accurate Measure of the Chlorophyll Content in Plants\n',
#     'article_link': '10.1016/s0034-4257(99)00023-1',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425799000231'}],
#   'satellite_formulas': [{'landsat7': '1'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'B6/B5'},
#    {'EnMAP': 'nan'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=83',
#   'name': 'Siliceous Rocks\r',
#   'abbreviation': '',
#   'formula': '[8475:8825]**2/([8125:8475]*[8925:9275])',
#   'references': [{'article_name': 'Ninomiya, Y. - Mapping quartz, carbonate minerals, and mafi cultramafic rocks using remotely sensed multispectral thermal infrared ASTER data\n',
#     'article_link': '',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': 'nan'},
#    {'landsat8': 'nan'},
#    {'aster': 'B11**2/(B10*B12)'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'nan'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=250',
#   'name': 'Chlorophyll Absorption Ratio Index 2\r',
#   'abbreviation': 'CARI2\r',
#   'formula': '[700]*([670]*(([700]-[550])/[150]) + [670] + [550] - (([700]-[550])/[150]*[550]) )/([670]*(((([700]-[550])/[150]))**2 + 1)**0.5)',
#   'references': [{'article_name': 'Kim, M. S. - The Use of Narrow Spectral Bands for Improving Remote Sensing Estimation of Fractionally Absorbed Photosynthetically Active Radiation (fAPAR)\n',
#     'article_link': '',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': 'nan'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'nan'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=108',
#   'name': 'Normalized Difference 1094/1205 Leaf water VI 2\r',
#   'abbreviation': 'LWVI-2\r',
#   'formula': '(1094nm - 1205nm)/(1094nm + 1205nm)',
#   'references': [{'article_name': 'GalvÃ£o, LÃªnio Soares; Formaggio, AntÃ´nio Roberto; Tisot, Daniela Arnold - Discrimination of sugarcane varieties in Southeastern Brazil with EO-1 Hyperion data\n',
#     'article_link': '10.1016/j.rse.2004.11.012',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425704003669'}],
#   'satellite_formulas': [{'landsat7': '0'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'nan'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=529',
#   'name': 'WI/NDVI\r',
#   'abbreviation': 'WI/NDVI\r',
#   'formula': '900nm*(680nm + 800nm)/(970nm*(-680nm + 800nm))',
#   'references': [{'article_name': 'Penuelas, J.; Pinol, J.; Ogaya, R.; Filella, I. - Estimation of plant water concentration by the reflectance Water Index WI (R900/R970)\n',
#     'article_link': '10.1080/014311697217396',
#     'article_doi': 'http://dx.doi.org/10.1080/014311697217396'}],
#   'satellite_formulas': [{'landsat7': 'nan'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': '-VNIR_79*(VNIR_50 + VNIR_67)/(VNIR_88*(VNIR_50 - VNIR_67))'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=197',
#   'name': 'MCARI/MTVI2\r',
#   'abbreviation': 'MCARI/MTVI2\r',
#   'formula': '0.666666666666667*700nm*(0.2*550nm - 670nm + 0.8*700nm)*sqrt(5*sqrt(670nm) - 6*800nm + (2*800nm + 1)**2 + 0.5)/(670nm*(1.3*550nm - 2.5*670nm + 1.2*800nm))',
#   'references': [{'article_name': 'Eitel, J. U. H.; Long, D. S.; Gessler, P. E.; Smith, A. M. S. - Using insitu measurements to evaluate the new RapidEyeâ„¢ satellite series for prediction of wheat nitrogen status\n',
#     'article_link': '10.1080/01431160701422213',
#     'article_doi': 'http://dx.doi.org/10.1080/01431160701422213'},
#    {'article_name': 'Hunt Jr., E. Raymond; Daughtry, C. S. T.;  Eitel, Jan U. H.;  Long, D. S. - Remote Sensing Leaf Chlorophyll Content Using a Visible Band Index\n',
#     'article_link': '',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': 'B8*(0.133333333333333*B2 - 0.666666666666667*B3 + 0.533333333333333*B8)*sqrt(5*sqrt(B3) + 4*B4**2 - 2*B4 + 1.5)/(B3*(1.3*B2 - 2.5*B3 + 1.2*B4))'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'B5*(0.133333333333333*B3 - 0.666666666666667*B4 + 0.533333333333333*B5)*sqrt(5*sqrt(B4) + 4*B8**2 - 2*B8 + 1.5)/(B4*(1.3*B3 - 2.5*B4 + 1.2*B8))'},
#    {'EnMAP': 'VNIR_53*(0.133333333333333*VNIR_28 - 0.666666666666667*VNIR_48 + 0.533333333333333*VNIR_53)*sqrt(5*sqrt(VNIR_48) + 4*VNIR_67**2 - 2*VNIR_67 + 1.5)/(VNIR_48*(1.3*VNIR_28 - 2.5*VNIR_48 + 1.2*VNIR_67))'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=188',
#   'name': 'Pan NDVI\r',
#   'abbreviation': 'PNDVI\r',
#   'formula': '(-485.0 - 560.0 + 1080.0 - 660.0)/(485.0 + 560.0 + 1080.0 + 660.0)',
#   'references': [{'article_name': 'Wang, Fu-min; Huang, Jing-feng; Tang, Yan-lin; Wang, Xiu-zhen - New Vegetation Index and Its Application in Estimating Leaf Area Index of Rice\n',
#     'article_link': '10.1016/s1672-6308(07)60027-4',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S1672630807600274'}],
#   'satellite_formulas': [{'landsat7': '-0.224416517055655'},
#    {'landsat8': '-0.224416517055655'},
#    {'aster': '-0.224416517055655'},
#    {'sentinel2': '-0.224416517055655'},
#    {'EnMAP': '-0.224416517055655'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=33',
#   'name': 'Host Rock\r',
#   'abbreviation': '',
#   'formula': '[2145:2185]/[2185:2225]',
#   'references': [],
#   'satellite_formulas': [{'landsat7': '1'},
#    {'landsat8': '1'},
#    {'aster': 'B5/B6'},
#    {'sentinel2': '1'},
#    {'EnMAP': 'nan'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=66',
#   'name': 'Normalized Difference 531/570 Photochemical Reflectance Index 531/570\r',
#   'abbreviation': 'PRI531/570\r',
#   'formula': '(531nm - 570nm)/(531nm + 570nm)',
#   'references': [{'article_name': 'Aparicio, N.; Villegas, D.; Royo, C.; Casadesus, J.; Araus, J. L. - Effect of sensor view angle on the assessment of agronomic traits by ground level hyper-spectral reflectance measurements in durum wheat under contrasting Mediterranean conditions\n',
#     'article_link': '10.1080/0143116031000116967',
#     'article_doi': 'http://dx.doi.org/10.1080/0143116031000116967'},
#    {'article_name': 'Gamon, J. A.; Serrano, L.; Surfus, J. S. - The photochemical reflectance index: an optical indicator of photosynthetic radiation use efficiency across species, functional types, and nutrient levels\n',
#     'article_link': '10.1007/s004420050337',
#     'article_doi': 'http://dx.doi.org/10.1007/s004420050337'},
#    {'article_name': 'Gamon, J. A.; Surfus, J. S. - Assessing leaf pigment content and activity with a reflectometer\n',
#     'article_link': '10.1046/j.1469-8137.1999.00424.x',
#     'article_doi': 'http://dx.doi.org/10.1046/j.1469-8137.1999.00424.x'},
#    {'article_name': 'Merton, R. N.  - Monitoringcommunityhysteresis using spectralshiftanalysis and the red-edgevegetationstressindex\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Penuelas, Josep; Filella, Iolanda; Gamon, John A. - Assessment of photosynthetic radiation-use efficiency with spectral reflectance\n',
#     'article_link': '10.1111/j.1469-8137.1995.tb03064.x',
#     'article_doi': 'http://dx.doi.org/10.1111/j.1469-8137.1995.tb03064.x'},
#    {'article_name': 'PeÃ±uelas, J.; Filella, I. - Visible and near-infrared reflectance techniques for diagnosing plant physiological status\n',
#     'article_link': '10.1016/S1360-1385(98)01213-8',
#     'article_doi': 'http://dx.doi.org/10.1016/S1360-1385%2898%2901213-8'},
#    {'article_name': 'Pu, Ruiliang; Gong, Peng; Yu, Qian - Comparative Analysis of EO-1 ALI and Hyperion, and Landsat ETM+ Data for Mapping Forest Crown Closure and Leaf Area Index\n',
#     'article_link': '',
#     'article_doi': 'http://www.mdpi.com/1424-8220/8/6/3744/'},
#    {'article_name': 'Royo, C.; Aparicio, N.; Villegas, D.; Casadesus, J.; Monneveux, P.; Araus, J. L. - Usefulness of spectral reflectance indices as durum wheat yield predictors under contrasting Mediterranean conditions\n',
#     'article_link': '10.1080/0143116031000150059',
#     'article_doi': 'http://dx.doi.org/10.1080/0143116031000150059'},
#    {'article_name': 'Sims, Daniel A.; Gamon, John A. - Relationships between leaf pigment content and spectral reflectance across a wide range of species, leaf structures and developmental stages\n',
#     'article_link': '10.1016/s0034-4257(02)00010-x',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S003442570200010X'},
#    {'article_name': 'Thenot, F.; MÃ©thy, M.; Winkel, T. - The Photochemical Reflectance Index (PRI) as a water-stress index\n',
#     'article_link': '10.1080/01431160210163100',
#     'article_doi': 'http://dx.doi.org/10.1080/01431160210163100'}],
#   'satellite_formulas': [{'landsat7': '0'},
#    {'landsat8': '0'},
#    {'aster': '0'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': '(VNIR_24 - VNIR_32)/(VNIR_24 + VNIR_32)'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=264',
#   'name': '[750:850]',
#   'abbreviation': 'AR750/850\r',
#   'formula': 'Averagereflectancebetween750nmand850nm',
#   'references': [{'article_name': 'Apan, Armando; Held, Alex; Phinn, Stuart; Markley, John - Formulation and assessment of narrow-band vegetation indices from EO-1 hyperion imagery for discriminating sugarcane disease\n',
#     'article_link': '',
#     'article_doi': 'http://eprints.usq.edu.au/8061/'},
#    {'article_name': 'Strachan, Ian B.; Pattey, Elizabeth; Boisvert, Johanne B. - Impact of nitrogen and environmental conditions on corn as detected by hyperspectral reflectance\n',
#     'article_link': '10.1016/s0034-4257(01)00299-1',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': 'AveragereflectancebetweenB8andB4'},
#    {'landsat8': 'AveragereflectancebetweennanandB5'},
#    {'aster': 'AveragereflectancebetweennanandB3'},
#    {'sentinel2': 'AveragereflectancebetweennanandB8'},
#    {'EnMAP': 'AveragereflectancebetweenVNIR_60andVNIR_73'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=520',
#   'name': 'Single Band 2250\r',
#   'abbreviation': 'SB2250\r',
#   'formula': '2250nm',
#   'references': [{'article_name': 'Curran, Paul J. - Remote sensing of foliar chemistry\n',
#     'article_link': '10.1016/0034-4257(89)90069-2',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/0034425789900692'}],
#   'satellite_formulas': [{'landsat7': 'B6'},
#    {'landsat8': 'B7'},
#    {'aster': 'B7'},
#    {'sentinel2': 'B13'},
#    {'EnMAP': 'SWIR_108'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=419',
#   'name': 'Normalized Difference 800/550 Green NDVI hyper 2\r',
#   'abbreviation': 'GNDVIhyper2\r',
#   'formula': '(-550nm + 800nm)/(550nm + 800nm)',
#   'references': [{'article_name': 'Main, Russell; Cho, Moses Azong; Mathieu, Renaud; Oâ€™Kennedy, Martha M.; Ramoelo, Abel; Koch, Susan - An investigation into robust spectral indices for leaf chlorophyll estimation\n',
#     'article_link': '10.1016/j.isprsjprs.2011.08.001',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S092427161100089X'}],
#   'satellite_formulas': [{'landsat7': '(-B2 + B4)/(B2 + B4)'},
#    {'landsat8': 'nan'},
#    {'aster': '(-B1 + B3)/(B1 + B3)'},
#    {'sentinel2': '(-B3 + B8)/(B3 + B8)'},
#    {'EnMAP': '(-VNIR_28 + VNIR_67)/(VNIR_28 + VNIR_67)'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=229',
#   'name': 'Cellulose absorption index 2\r',
#   'abbreviation': 'CAI\r',
#   'formula': '0',
#   'references': [{'article_name': 'Daughtry, C.; Hunt, E. R.; Walthall, C. L.; Gish, T. J.; Liang, Shunlin; Kramer, E.J. - Assessing the Spatial Distribution of Plant Litter\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Daughtry, Craig S. T. - Discriminating crop residues from soil by shortwave infrared reflectance\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Nagler, P. L; Daughtry, C. S. T.; Goward, S. N. - Plant Litter and Soil Reflectance\n',
#     'article_link': '10.1016/s0034-4257(99)00082-6',
#     'article_doi': ''},
#    {'article_name': 'Oppelt, N.; Mauser, W. - Hyperspectral monitoring of physiological parameters of wheat during a vegetation period using AVIS data\n',
#     'article_link': '10.1080/0143116031000115300',
#     'article_doi': 'http://www.ingentaconnect.com/content/tandf/tres/2004/00000025/00000001/art00011%20http://dx.doi.org/10.1080/0143116031000115300'}],
#   'satellite_formulas': [{'landsat7': '0'},
#    {'landsat8': '0'},
#    {'aster': '0'},
#    {'sentinel2': '0'},
#    {'EnMAP': '0'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=104',
#   'name': 'Weighted Difference Vegetation Index\r',
#   'abbreviation': 'WDVI\r',
#   'formula': '1080.0 - 660.0*a',
#   'references': [{'article_name': 'Baret, F.; Guyot, G. - Potentials and limits of vegetation indices for LAI and APAR assessment\n',
#     'article_link': '',
#     'article_doi': 'http://www.sciencedirect.com/science/article/B6V6V-48BK8FF-1B/2/44379b7ec48e94418f4bd5657f05ec0e'},
#    {'article_name': 'Buschmann, Claus - Fernerkundung von Pflanzen - Ausbreitung, Gesundheitszustand und Produktivitfit\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Chen, J.M. - Evaluation of vegetation indices and a modified simple ratio for boreal applications\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Clevers, J. G. P. W. - Application of a weighted infrared-red vegetation index for estimating leaf Area Index by Correcting for Soil Moisture\n',
#     'article_link': '10.1016/0034-4257(89)90076-x',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/003442578990076X'},
#    {'article_name': 'Clevers, J. G. P. W.; BÃ¼ker, C.; van Leeuwen, H. J. C.; Bouman, B. A. M. - A framework for monitoring crop growth by combining directional and spectral remote sensing information\n',
#     'article_link': '10.1016/0034-4257(94)90042-6',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/0034425794900426'},
#    {'article_name': 'Dorigo, W. A.; Zurita-Milla, R.; de Wit, A. J. W.; Brazile, J.; Singh, R.; Schaepman, M. E. - A review on reflective remote sensing and data assimilation techniques for enhanced agroecosystem modeling\n',
#     'article_link': '10.1016/j.jag.2006.05.003',
#     'article_doi': 'http://apps.webofknowledge.com/InboundService.do?Func=Frame&product=WOS&action=retrieve&SrcApp=EndNote&Init=Yes&SrcAuth=ResearchSoft&mode=FullRecord&UT=000246320700008'},
#    {'article_name': 'Ehammer, Andrea; Fritsch, Sebastian; Conrad, Christopher; Lamers, John; Dech, Stefan - Statistical derivation of fPAR and LAI for irrigated cotton and rice in arid Uzbekistan by combining multi-temporal RapidEye data and ground measurements\n',
#     'article_link': '',
#     'article_doi': 'http://link.aip.org/link/PSISDG/v7824/i1/p782409/s1&Agg=doi'},
#    {'article_name': 'Goel, Narendra S.; Qin, Wenhan - Influences of canopy architecture on relationships between various vegetation indices and LAI and Fpar: A computer simulation\n',
#     'article_link': '10.1080/02757259409532252',
#     'article_doi': 'http://dx.doi.org/10.1080/02757259409532252'},
#    {'article_name': 'Leprieur, C.; Kerr, Y. H.; Pichon, J. M. - Critical assessment of vegetation indices from AVHRR in a semi-arid environment\n',
#     'article_link': '10.1080/01431169608949092',
#     'article_doi': 'http://www.tandfonline.com/doi/abs/10.1080/01431169608949092'},
#    {'article_name': 'Qi, J.; Chehbouni, A.; Huete, A. R.; Kerr, Y. H.; Sorooshian, S. - A modified soil adjusted vegetation index\n',
#     'article_link': '10.1016/0034-4257(94)90134-1',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/0034425794901341'},
#    {'article_name': 'Schmidt, H.; Karnieli, A. - Sensitivity of vegetation indices to substrate brightness in hyper-arid environment: The Makhtesh Ramon Crater (Israel) case study\n',
#     'article_link': '10.1080/01431160110063779',
#     'article_doi': 'http://dx.doi.org/10.1080/01431160110063779'}],
#   'satellite_formulas': [{'landsat7': '1080.0 - 660.0*a'},
#    {'landsat8': '1080.0 - 660.0*a'},
#    {'aster': '1080.0 - 660.0*a'},
#    {'sentinel2': '1080.0 - 660.0*a'},
#    {'EnMAP': '1080.0 - 660.0*a'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=140',
#   'name': 'Single Band 703 Boochs\r',
#   'abbreviation': 'SB703\r',
#   'formula': '703nm',
#   'references': [{'article_name': 'Boochs, F.; Kupfer, G.; Dockter, K.; KÃ¼hbauch, W. - Shape of the red edge as vitality indicator for plants\n',
#     'article_link': '10.1080/01431169008955127',
#     'article_doi': ''},
#    {'article_name': 'le Maire, G.; Francois, C.; Dufrene, E. - Towards universal broad leaf chlorophyll indices using PROSPECT simulated database and hyperspectral reflectance measurements\n',
#     'article_link': '10.1016/j.rse.2003.09.004',
#     'article_doi': ''},
#    {'article_name': 'Main, Russell; Cho, Moses Azong; Mathieu, Renaud; Oâ€™Kennedy, Martha M.; Ramoelo, Abel; Koch, Susan - An investigation into robust spectral indices for leaf chlorophyll estimation\n',
#     'article_link': '10.1016/j.isprsjprs.2011.08.001',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S092427161100089X'}],
#   'satellite_formulas': [{'landsat7': 'B8'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'B5'},
#    {'EnMAP': 'VNIR_53'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=4',
#   'name': 'Atmospherically Resistant Vegetation Index\r',
#   'abbreviation': 'ARVI\r',
#   'formula': '(1080.0 - 660.0 + y*(-485.0 + 660.0))/(1080.0 + 660.0 - y*(-485.0 + 660.0))',
#   'references': [{'article_name': 'Bannari, A.; Morin, D.; Bonn, F.; Huete, A. R. - A review of vegetation indices\n',
#     'article_link': '10.1080/02757259509532298',
#     'article_doi': 'http://dx.doi.org/10.1080/02757259509532298'},
#    {'article_name': 'Ehammer, Andrea; Fritsch, Sebastian; Conrad, Christopher; Lamers, John; Dech, Stefan - Statistical derivation of fPAR and LAI for irrigated cotton and rice in arid Uzbekistan by combining multi-temporal RapidEye data and ground measurements\n',
#     'article_link': '',
#     'article_doi': 'http://link.aip.org/link/PSISDG/v7824/i1/p782409/s1&Agg=doi'},
#    {'article_name': 'Gao, Bo-cai - NDWIâ€”A normalized difference water index for remote sensing of vegetation liquid water from space\n',
#     'article_link': '10.1016/s0034-4257(96)00067-3',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425796000673'},
#    {'article_name': 'Gitelson, A. A.; Kaufman, Y. J.; Stark, R.; Rundquist, D. - Novel algorithms for remote estimation of vegetation fraction\n',
#     'article_link': '10.1016/s0034-4257(01)00289-9',
#     'article_doi': 'http://www.ingentaconnect.com/content/els/00344257/2002/00000080/00000001/art00289%20http://dx.doi.org/10.1016/S0034-4257%2801%2900289-9'},
#    {'article_name': 'Gitelson, Anatoly A. - Wide Dynamic Range Vegetation Index for Remote Quantification of Biophysical Characteristics of Vegetation\n',
#     'article_link': '10.1078/0176-1617-01176',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0176161704705726'},
#    {'article_name': 'Gitelson, Anatoly A.; Kaufman, Yoram J.; Merzlyak, Mark N. - Use of a green channel in remote sensing of global vegetation from EOS-MODIS\n',
#     'article_link': '10.1016/s0034-4257(96)00072-7',
#     'article_doi': ''},
#    {'article_name': 'Gitelson, Anatoly A.; ViÃ±a, AndrÃ©s; Arkebauer, Timothy J.; Rundquist, Donald C.; Keydan, Galina: Leavitt, Bryan - Remote estimation of leaf area index and green leaf biomass in maize canopies\n',
#     'article_link': '10.1029/2002gl016450',
#     'article_doi': ''},
#    {'article_name': 'Huete, A. R.; Liu, H. Q.; Batchily, K.; van Leeuwen, W. - A comparison of vegetation indices over a global set of TM images for EOS-MODIS\n',
#     'article_link': '10.1016/s0034-4257(96)00112-5',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425796001125'},
#    {'article_name': 'Huete, A.R.; Justice, C.; Liu, H. - Development of Vegetation and Soil Indices for MODIS- EOS\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Jacobsen, Anne; Broge, Niels H.; Hansen, Birger U. - Monitoring wheat fields and grasslands using spectral reflectance data\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Karnieli, A.; Kaufman, Y. J.; Remer, L.; Wald, A. - AFRI - aerosol free vegetation index\n',
#     'article_link': '10.1016/s0034-4257(01)00190-0',
#     'article_doi': 'http://www.ingentaconnect.com/content/els/00344257/2001/00000077/00000001/art00190%20http://dx.doi.org/10.1016/S0034-4257%2801%2900190-0'},
#    {'article_name': 'Metternicht, G. - Vegetation indices derived from high-resolution airborne videography for precision crop management\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Rondeaux, GeneviÃ¨ve; Steven, Michael; Baret, FrÃ©dÃ©ric - Optimization of soil-adjusted vegetation indices\n',
#     'article_link': '10.1016/0034-4257(95)00186-7',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/0034425795001867'},
#    {'article_name': 'Thenkabail, P. S.; Smith, R. B.; De Pauw, E. - Evaluation of narrowband and broadband vegetation indices for determining optimal hyperspectral wavebands for agricultural crop characterization\n',
#     'article_link': '',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': '(-175.0*y - 420.0)/(175.0*y - 1740.0)'},
#    {'landsat8': '(-175.0*y - 420.0)/(175.0*y - 1740.0)'},
#    {'aster': '(-175.0*y - 420.0)/(175.0*y - 1740.0)'},
#    {'sentinel2': '(-175.0*y - 420.0)/(175.0*y - 1740.0)'},
#    {'EnMAP': '(-175.0*y - 420.0)/(175.0*y - 1740.0)'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=65',
#   'name': 'Phengitic\r',
#   'abbreviation': '',
#   'formula': '[2145:2185]/[2185:2225]',
#   'references': [{'article_name': 'Hewson, Rob D.; Cudahy, T. J.; Huntington, J. F. - Geologic and alteration mapping at Mt Fitton, South Australia, using ASTER satellite-borne data\n',
#     'article_link': '10.1109/igarss.2001.976615',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': '1'},
#    {'landsat8': '1'},
#    {'aster': 'B5/B6'},
#    {'sentinel2': '1'},
#    {'EnMAP': 'nan'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=557',
#   'name': 'Simple Ratio 683/510\r',
#   'abbreviation': 'SR683/510\r',
#   'formula': '683nm/510nm',
#   'references': [{'article_name': 'Underwood, Emma; Ustin, Susan; DiPietro, Deanne - Mapping nonnative plants using hyperspectral imagery\n',
#     'article_link': '10.1016/s0034-4257(03)00096-8',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425703000968'}],
#   'satellite_formulas': [{'landsat7': 'B3/B1'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'VNIR_50/VNIR_20'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=3',
#   'name': 'Amphibole\r',
#   'abbreviation': '',
#   'formula': '[2185:2225]/[2295:2365]',
#   'references': [{'article_name': 'ENVI Help\n',
#     'article_link': '',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': 'nan'},
#    {'landsat8': 'nan'},
#    {'aster': 'B6/B8'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'nan'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=480',
#   'name': 'Browning Reflectance Index\r',
#   'abbreviation': 'BRI\r',
#   'formula': '(-1/700nm + 1/550nm)/1080.0',
#   'references': [{'article_name': 'Merzlyak, M. N.; Gitelson, A. A.; Chivkunova, O. B.; Solovchenko, A. E.; Pogosyan, S. I. - Application of Reflectance Spectroscopy for Analysis of Higher Plant Pigments\n',
#     'article_link': '',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': '-0.000925925925925926/B8 + 0.000925925925925926/B2'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': '-0.000925925925925926/B5 + 0.000925925925925926/B3'},
#    {'EnMAP': '-0.000925925925925926/VNIR_53 + 0.000925925925925926/VNIR_28'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=41',
#   'name': 'Modified Chlorophyll Absorption in Reflectance Index\r',
#   'abbreviation': 'MCARI\r',
#   'formula': '700nm*(0.2*550nm - 670nm + 0.8*700nm)/670nm',
#   'references': [{'article_name': 'Apan, Armando; Held, Alex; Phinn, Stuart; Markley, John - Formulation and assessment of narrow-band vegetation indices from EO-1 hyperion imagery for discriminating sugarcane disease\n',
#     'article_link': '',
#     'article_doi': 'http://eprints.usq.edu.au/8061/'},
#    {'article_name': 'Daughtry, C. S. T.; Walthall, C. L.; Kim, M. S.; de Colstoun, E. Brown; McMurtrey Iii, J. E. - Estimating Corn Leaf Chlorophyll Concentration from Leaf and Canopy Reflectance\n',
#     'article_link': '10.1016/s0034-4257(00)00113-9',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425700001139'},
#    {'article_name': 'Eitel, J. U. H.; Long, D. S.; Gessler, P. E.; Smith, A. M. S. - Using insitu measurements to evaluate the new RapidEyeâ„¢ satellite series for prediction of wheat nitrogen status\n',
#     'article_link': '10.1080/01431160701422213',
#     'article_doi': 'http://dx.doi.org/10.1080/01431160701422213'},
#    {'article_name': 'GalvÃ£o, LÃªnio Soares; Formaggio, AntÃ´nio Roberto; Tisot, Daniela Arnold - Discrimination of sugarcane varieties in Southeastern Brazil with EO-1 Hyperion data\n',
#     'article_link': '10.1016/j.rse.2004.11.012',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425704003669'},
#    {'article_name': 'Haboudane, Driss; Miller, John R.; Pattey, Elizabeth; Zarco-Tejada, Pablo J.; Strachan, Ian B. - Hyperspectral vegetation indices and novel algorithms for predicting green LAI of crop canopies: Modeling and validation in the context of precision agriculture\n',
#     'article_link': '10.1016/j.rse.2003.12.013',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425704000264'},
#    {'article_name': 'Haboudane, Driss; Miller, John R.; Tremblay, Nicolas; Zarco-Tejada, Pablo J.; Dextraze, Louise - Integrated narrow-band vegetation indices for prediction of crop chlorophyll content for application to precision agriculture\n',
#     'article_link': '10.1016/s0034-4257(02)00018-4',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425702000184'},
#    {'article_name': 'Herrmann, I.; Karnieli, A.; Bonfil, D. J.; Cohen, Y.; Alchanatis, V. - SWIR-based spectral indices for assessing nitrogen content in potato fields\n',
#     'article_link': '10.1080/01431160903283892',
#     'article_doi': 'http://dx.doi.org/10.1080/01431160903283892'},
#    {'article_name': 'Hunt Jr., E. Raymond; Daughtry, C. S. T.;  Eitel, Jan U. H.;  Long, D. S. - Remote Sensing Leaf Chlorophyll Content Using a Visible Band Index\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Wu, Chaoyang; Niu, Zheng; Tang, Quan; Huang, Wenjiang - Estimating chlorophyll content from hyperspectral vegetation indices: Modeling and validation\n',
#     'article_link': '10.1016/j.agrformet.2008.03.005',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0168192308000920'},
#    {'article_name': 'Zarco-Tejada P.J.; Sepulcre-CantÃ³, G. - REMOTE SENSING OF VEGETATION BIOPHYSICAL PARAMETERS FOR DETECTING STRESS CONDITION AND LAND COVER CHANGES\n',
#     'article_link': '',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': 'B8*(0.2*B2 - B3 + 0.8*B8)/B3'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'B5*(0.2*B3 - B4 + 0.8*B5)/B4'},
#    {'EnMAP': 'VNIR_53*(0.2*VNIR_28 - VNIR_48 + 0.8*VNIR_53)/VNIR_48'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=515',
#   'name': 'Single Band 2080\r',
#   'abbreviation': 'SB2080\r',
#   'formula': '2080nm',
#   'references': [{'article_name': 'Curran, Paul J. - Remote sensing of foliar chemistry\n',
#     'article_link': '10.1016/0034-4257(89)90069-2',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/0034425789900692'}],
#   'satellite_formulas': [{'landsat7': 'nan'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'SWIR_88'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=260',
#   'name': 'Normalized Difference 800/680  Pigment specific normalised difference A2, Lichtenthaler indices 1, NDVIhyper\r',
#   'abbreviation': 'ND800/680\r',
#   'formula': '(-680nm + 800nm)/(680nm + 800nm)',
#   'references': [{'article_name': 'Apan, Armando; Held, Alex; Phinn, Stuart; Markley, John - Formulation and assessment of narrow-band vegetation indices from EO-1 hyperion imagery for discriminating sugarcane disease\n',
#     'article_link': '',
#     'article_doi': 'http://eprints.usq.edu.au/8061/'},
#    {'article_name': 'Blackburn, G. A. - Spectral indices for estimating photosynthetic pigment concentrations: A test using senescent tree leaves\n',
#     'article_link': '10.1080/014311698215919',
#     'article_doi': 'http://dx.doi.org/10.1080/014311698215919'},
#    {'article_name': 'le Maire, G.; Francois, C.; Dufrene, E. - Towards universal broad leaf chlorophyll indices using PROSPECT simulated database and hyperspectral reflectance measurements\n',
#     'article_link': '10.1016/j.rse.2003.09.004',
#     'article_doi': ''},
#    {'article_name': 'Lichtenthaler, Hartmut K. - Vegetation Stress: an Introduction to the Stress Concept in Plants\n',
#     'article_link': '10.1016/s0176-1617(96)80287-2',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0176161796802872'},
#    {'article_name': 'Main, Russell; Cho, Moses Azong; Mathieu, Renaud; Oâ€™Kennedy, Martha M.; Ramoelo, Abel; Koch, Susan - An investigation into robust spectral indices for leaf chlorophyll estimation\n',
#     'article_link': '10.1016/j.isprsjprs.2011.08.001',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S092427161100089X'},
#    {'article_name': 'Penuelas, J.; Pinol, J.; Ogaya, R.; Filella, I. - Estimation of plant water concentration by the reflectance Water Index WI (R900/R970)\n',
#     'article_link': '10.1080/014311697217396',
#     'article_doi': 'http://dx.doi.org/10.1080/014311697217396'},
#    {'article_name': 'Rouse, J.W., Jr.; Haas,R.H.;  Schell, J.A.; Deering, D.W.  - Monitoring the vernal advancement and retrogradation (green wave effect) of natural vegetation\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Sims, Daniel A.; Gamon, John A. - Relationships between leaf pigment content and spectral reflectance across a wide range of species, leaf structures and developmental stages\n',
#     'article_link': '10.1016/s0034-4257(02)00010-x',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S003442570200010X'},
#    {'article_name': 'Wu, Chaoyang; Niu, Zheng; Tang, Quan; Huang, Wenjiang - Estimating chlorophyll content from hyperspectral vegetation indices: Modeling and validation\n',
#     'article_link': '10.1016/j.agrformet.2008.03.005',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0168192308000920'},
#    {'article_name': 'Zarco-Tejada, P. J.; Miller, J. R.; Noland, T. L.; Mohammed, G. H.; Sampson, P. H.  - Scaling-up and model inversion methods with narrow-band optical indices for chlorophyll content estimation in closed forest canopies with hyperspectral data\n',
#     'article_link': '',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': '(-B3 + B4)/(B3 + B4)'},
#    {'landsat8': 'nan'},
#    {'aster': '(-B2 + B3)/(B2 + B3)'},
#    {'sentinel2': '(-B4 + B8)/(B4 + B8)'},
#    {'EnMAP': '(-VNIR_50 + VNIR_67)/(VNIR_50 + VNIR_67)'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=278',
#   'name': 'Normalized Difference 790/670\r',
#   'abbreviation': 'ND790/670\r',
#   'formula': '(-670nm + 790nm)/(670nm + 790nm)',
#   'references': [{'article_name': 'Barnes, E.M.; Clarke, T.R.; Richards, S.E.; Colaizzi, P.D.; Haberland, J.; Kostrzewski, M.; Waller, P.; Choi, C., Riley, E.; Thompson, T.; Lascano, R.J.; Li, H.; Moran, M.S. - Coincident detection of crop water stress, nitrogen status and canopy density using ground based multispectral data\n',
#     'article_link': '',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': '(-B3 + B4)/(B3 + B4)'},
#    {'landsat8': 'nan'},
#    {'aster': '(-B2 + B3)/(B2 + B3)'},
#    {'sentinel2': '(-B4 + B7)/(B4 + B7)'},
#    {'EnMAP': '(-VNIR_48 + VNIR_65)/(VNIR_48 + VNIR_65)'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=371',
#   'name': 'Simple Ratio 750/555\r',
#   'abbreviation': 'SR750/555\r',
#   'formula': '750nm/555nm',
#   'references': [{'article_name': 'Gitelson, Anatoly; Merzlyak, Mark N. - Quantitative estimation of chlorophyll-a using reflectance spectra: Experiments with autumn chestnut and maple leaves\n',
#     'article_link': '10.1016/1011-1344(93)06963-4',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': 'B8/B2'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'VNIR_60/VNIR_29'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=57',
#   'name': 'Normalized Difference Salinity Index\r',
#   'abbreviation': 'NDSI\r',
#   'formula': '([1600:1700] - [2145:2185])/([1600:1700] + [2145:2185])',
#   'references': [{'article_name': 'Al-Khaier - Soil Salinity Detection Using Satellite Remotes Sensing\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Richardson, Andrew D.; Duigan, Shane P.; Berlyn, Graeme P. - An evaluation of noninvasive methods to estimate foliar chlorophyll content\n',
#     'article_link': '10.1046/j.0028-646X.2001.00289.x',
#     'article_doi': 'http://dx.doi.org/10.1046/j.0028-646X.2001.00289.x'}],
#   'satellite_formulas': [{'landsat7': '(B5 - B6)/(B5 + B6)'},
#    {'landsat8': 'nan'},
#    {'aster': '(B4 - B5)/(B4 + B5)'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'nan'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=381',
#   'name': 'Optimized Soil Adjusted Vegetation Index 1510\r',
#   'abbreviation': 'OSAVI1510\r',
#   'formula': '(-1510nm + 800nm)*(0.16 + 1)/(1510nm + 800nm + 0.16)',
#   'references': [{'article_name': 'Herrmann, I.; Karnieli, A.; Bonfil, D. J.; Cohen, Y.; Alchanatis, V. - SWIR-based spectral indices for assessing nitrogen content in potato fields\n',
#     'article_link': '10.1080/01431160903283892',
#     'article_doi': 'http://dx.doi.org/10.1080/01431160903283892'}],
#   'satellite_formulas': [{'landsat7': 'nan'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': '1.16*(-SWIR_49 + VNIR_67)/(SWIR_49 + VNIR_67 + 0.16)'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=75',
#   'name': 'Reduced Simple Ratio\r',
#   'abbreviation': 'RSR\r',
#   'formula': '-[1400:3000]/[3000] + [3000]*[780]/[640:760] + [1400]',
#   'references': [{'article_name': 'Heiskanen, J. - Estimating aboveground tree biomass and leaf area index in a mountain birch forest using ASTER satellite data\n',
#     'article_link': '10.1080/01431160500353858',
#     'article_doi': 'http://www.tandfonline.com/doi/abs/10.1080/01431160500353858'}],
#   'satellite_formulas': [{'landsat7': 'nan'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'nan'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=308',
#   'name': 'Single Band 635 Blackburn2\r',
#   'abbreviation': 'BB2\r',
#   'formula': '635nm',
#   'references': [{'article_name': 'Blackburn, G. A. - Spectral indices for estimating photosynthetic pigment concentrations: A test using senescent tree leaves\n',
#     'article_link': '10.1080/014311698215919',
#     'article_doi': 'http://dx.doi.org/10.1080/014311698215919'},
#    {'article_name': 'Richardson, Andrew D.; Duigan, Shane P.; Berlyn, Graeme P. - An evaluation of noninvasive methods to estimate foliar chlorophyll content\n',
#     'article_link': '10.1046/j.0028-646X.2001.00289.x',
#     'article_doi': 'http://dx.doi.org/10.1046/j.0028-646X.2001.00289.x'}],
#   'satellite_formulas': [{'landsat7': 'B3'},
#    {'landsat8': 'B8'},
#    {'aster': 'B2'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'VNIR_43'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=492',
#   'name': 'Single Band 930\r',
#   'abbreviation': 'SB930\r',
#   'formula': '930nm',
#   'references': [{'article_name': 'Curran, Paul J. - Remote sensing of foliar chemistry\n',
#     'article_link': '10.1016/0034-4257(89)90069-2',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/0034425789900692'}],
#   'satellite_formulas': [{'landsat7': 'nan'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'VNIR_83'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=56',
#   'name': 'Normalized Difference 820/1600 Normalized Difference Moisture Index\r',
#   'abbreviation': 'NDMI\r',
#   'formula': '(-1600nm + 820nm)/(1600nm + 820nm)',
#   'references': [{'article_name': 'Cibula, W. G.; Zetka, E. F.; Rickman, D. L. - Response of thematic mapper bands to plant water stress\n',
#     'article_link': '10.1080/01431169208904236',
#     'article_doi': 'http://dx.doi.org/10.1080/01431169208904236'},
#    {'article_name': 'GalvÃ£o, LÃªnio Soares; Formaggio, AntÃ´nio Roberto; Tisot, Daniela Arnold - Discrimination of sugarcane varieties in Southeastern Brazil with EO-1 Hyperion data\n',
#     'article_link': '10.1016/j.rse.2004.11.012',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425704003669'},
#    {'article_name': 'Hardisky, M. A .; Klemas, V.; Smart, R.M. - The Influence of Soil Salinity, Growth Form, and Leaf Moisture on the Spectral Radiance of Spartina alterniflora Canopies\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Wilson, Emily Hoffhine; Sader, Steven A. - Detection of forest harvest type using multiple dates of Landsat TM imagery\n',
#     'article_link': '10.1016/s0034-4257(01)00318-2',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425701003182'}],
#   'satellite_formulas': [{'landsat7': '(B4 - B5)/(B4 + B5)'},
#    {'landsat8': 'nan'},
#    {'aster': '(B3 - B4)/(B3 + B4)'},
#    {'sentinel2': '(-B12 + B8)/(B12 + B8)'},
#    {'EnMAP': '(-SWIR_57 + VNIR_69)/(SWIR_57 + VNIR_69)'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=152',
#   'name': 'Simple Ratio 754/704 Datt3\r',
#   'abbreviation': 'Datt3\r',
#   'formula': '754nm/704nm',
#   'references': [{'article_name': 'Datt, Bisun - Remote Sensing of Water Content in Eucalyptus Leaves\n',
#     'article_link': 'http://dx.doi.org/10.1071/BT98042',
#     'article_doi': ''},
#    {'article_name': 'le Maire, G.; Francois, C.; Dufrene, E. - Towards universal broad leaf chlorophyll indices using PROSPECT simulated database and hyperspectral reflectance measurements\n',
#     'article_link': '10.1016/j.rse.2003.09.004',
#     'article_doi': ''},
#    {'article_name': 'Main, Russell; Cho, Moses Azong; Mathieu, Renaud; Oâ€™Kennedy, Martha M.; Ramoelo, Abel; Koch, Susan - An investigation into robust spectral indices for leaf chlorophyll estimation\n',
#     'article_link': '10.1016/j.isprsjprs.2011.08.001',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S092427161100089X'}],
#   'satellite_formulas': [{'landsat7': '1'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'VNIR_61/VNIR_54'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=155',
#   'name': 'Datt6\r',
#   'abbreviation': 'Datt6\r',
#   'formula': '860nm/(550nm*708nm)',
#   'references': [{'article_name': 'Datt, Bisun - Remote Sensing of Chlorophyll a, Chlorophyll b, Chlorophyll a+b, and Total Carotenoid Content in Eucalyptus Leaves\n',
#     'article_link': '10.1016/s0034-4257(98)00046-7',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425798000467'},
#    {'article_name': 'le Maire, G.; Francois, C.; Dufrene, E. - Towards universal broad leaf chlorophyll indices using PROSPECT simulated database and hyperspectral reflectance measurements\n',
#     'article_link': '10.1016/j.rse.2003.09.004',
#     'article_doi': ''},
#    {'article_name': 'Main, Russell; Cho, Moses Azong; Mathieu, Renaud; Oâ€™Kennedy, Martha M.; Ramoelo, Abel; Koch, Susan - An investigation into robust spectral indices for leaf chlorophyll estimation\n',
#     'article_link': '10.1016/j.isprsjprs.2011.08.001',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S092427161100089X'}],
#   'satellite_formulas': [{'landsat7': 'B4/(B2*B8)'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'B8/(B3*B5)'},
#    {'EnMAP': 'VNIR_74/(VNIR_28*VNIR_54)'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=99',
#   'name': 'Triangular Vegetation Index\r',
#   'abbreviation': 'TVI\r',
#   'formula': '40.0*550nm - 100.0*670nm + 60.0*750nm',
#   'references': [{'article_name': 'Broge, N. H.; Leblanc, E. - Comparing prediction power and stability of broadband and hyperspectral vegetation indices for estimation of green leaf area index and canopy chlorophyll density\n',
#     'article_link': '10.1016/s0034-4257(00)00197-8',
#     'article_doi': ''},
#    {'article_name': 'Eitel, J. U. H.; Long, D. S.; Gessler, P. E.; Smith, A. M. S. - Using insitu measurements to evaluate the new RapidEyeâ„¢ satellite series for prediction of wheat nitrogen status\n',
#     'article_link': '10.1080/01431160701422213',
#     'article_doi': 'http://dx.doi.org/10.1080/01431160701422213'},
#    {'article_name': 'Haboudane, Driss; Miller, John R.; Pattey, Elizabeth; Zarco-Tejada, Pablo J.; Strachan, Ian B. - Hyperspectral vegetation indices and novel algorithms for predicting green LAI of crop canopies: Modeling and validation in the context of precision agriculture\n',
#     'article_link': '10.1016/j.rse.2003.12.013',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425704000264'},
#    {'article_name': 'le Maire, G.; Francois, C.; Dufrene, E. - Towards universal broad leaf chlorophyll indices using PROSPECT simulated database and hyperspectral reflectance measurements\n',
#     'article_link': '10.1016/j.rse.2003.09.004',
#     'article_doi': ''},
#    {'article_name': 'Main, Russell; Cho, Moses Azong; Mathieu, Renaud; Oâ€™Kennedy, Martha M.; Ramoelo, Abel; Koch, Susan - An investigation into robust spectral indices for leaf chlorophyll estimation\n',
#     'article_link': '10.1016/j.isprsjprs.2011.08.001',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S092427161100089X'},
#    {'article_name': 'Richardson, A.J.; Wiegand, C.L. - Distinguishing vegetation from soil background information\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Rouse, J.W., Jr.; Haas,R.H.;  Schell, J.A.; Deering, D.W.  - Monitoring the vernal advancement and retrogradation (green wave effect) of natural vegetation\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Rouse, J.W.; Haas, R.H.; Schell, J.A.; Deering, D.W. - Monitoring vegetation systems in the Great Plains with ERTS\n',
#     'article_link': '',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': '40.0*B2 - 100.0*B3 + 60.0*B8'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': '40.0*VNIR_28 - 100.0*VNIR_48 + 60.0*VNIR_60'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=55',
#   'name': 'Normalized Difference Lignin Index\r',
#   'abbreviation': 'NDLI\r',
#   'formula': '(log([1754]) - log([1680]))/(log([1754]) + log([1680]))',
#   'references': [{'article_name': 'Serrano, Lydia; PeÃ±uelas, Josep; Ustin, Susan L. - Remote sensing of nitrogen and lignin in Mediterranean vegetation from AVIRIS data: Decomposing biochemical from structural signals\n',
#     'article_link': '10.1016/s0034-4257(02)00011-1',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425702000111'}],
#   'satellite_formulas': [{'landsat7': 'nan'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'nan'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=184',
#   'name': 'Transformed Chlorophyll Absorbtion Ratio 2\r',
#   'abbreviation': 'TCARI2\r',
#   'formula': '6*750nm*(-550nm + 750nm)*(-705nm + 750nm)/705nm',
#   'references': [{'article_name': 'Main, Russell; Cho, Moses Azong; Mathieu, Renaud; Oâ€™Kennedy, Martha M.; Ramoelo, Abel; Koch, Susan - An investigation into robust spectral indices for leaf chlorophyll estimation\n',
#     'article_link': '10.1016/j.isprsjprs.2011.08.001',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S092427161100089X'}],
#   'satellite_formulas': [{'landsat7': '0'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': '6*VNIR_60*(VNIR_28 - VNIR_60)*(VNIR_54 - VNIR_60)/VNIR_54'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/r-single.php?id=375',
#   'name': 'Brunn, A.; Busch, W.; Dittmann, C.; Fischer, C.; Vosen, P.\r',
#   'abbreviation': 'Monitoring Mining Induced Plant Alteration and Change Detection in a German Coal Mining Area using Airborne Hyperspectral Imagery\r',
#   'formula': "Can't parse",
#   'references': [],
#   'satellite_formulas': [{'landsat7': "Can't parse"},
#    {'landsat8': "Can't parse"},
#    {'aster': "Can't parse"},
#    {'sentinel2': "Can't parse"},
#    {'EnMAP': "Can't parse"}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=230',
#   'name': 'Amphibole / MgOH\r',
#   'abbreviation': '',
#   'formula': '([2185:2225] + [2360:2430])/[2295:2365]',
#   'references': [{'article_name': 'ENVI Help\n',
#     'article_link': '',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': 'nan'},
#    {'landsat8': 'nan'},
#    {'aster': '(B6 + B9)/B8'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'nan'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=541',
#   'name': 'Mid-infrared vegetation index\r',
#   'abbreviation': 'MVI\r',
# ...
#     'article_link': '10.1016/0034-4257(93)90088-f',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/003442579390088F'},
#    {'article_name': 'Pinter, P. J.; Hatfield, J. L.; Schepers, J. S.; Barnes, E. M.; Moran, M. S.; Daughtry, C. S. T.; Upchurch, D. R. - Remote sensing for crop management\n',
#     'article_link': '',
#     'article_doi': 'http://apps.webofknowledge.com/InboundService.do?Func=Frame&product=WOS&action=retrieve&SrcApp=EndNote&Init=Yes&SrcAuth=ResearchSoft&mode=FullRecord&UT=000221193400006'},
#    {'article_name': 'Pinty, B.; Verstraete, M. M. - GEMI: a non-linear index to monitor global vegetation from satellites\n',
#     'article_link': '10.1007/bf00031911',
#     'article_doi': 'http://dx.doi.org/10.1007/BF00031911'},
#    {'article_name': 'Pu, Ruiliang; Gong, Peng; Yu, Qian - Comparative Analysis of EO-1 ALI and Hyperion, and Landsat ETM+ Data for Mapping Forest Crown Closure and Leaf Area Index\n',
#     'article_link': '',
#     'article_doi': 'http://www.mdpi.com/1424-8220/8/6/3744/'},
#    {'article_name': 'Qi, J.; Chehbouni, A.; Huete, A. R.; Kerr, Y. H.; Sorooshian, S. - A modified soil adjusted vegetation index\n',
#     'article_link': '10.1016/0034-4257(94)90134-1',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/0034425794901341'},
#    {'article_name': 'Ricotta, Carlo; Avena, Giancarlo; De Palma, Alessandra - Mapping and monitoring net primary productivity with AVHRR NDVI time-series: statistical equivalence of cumulative vegetation indices\n',
#     'article_link': '10.1016/s0924-2716(99)00028-3',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0924271699000283'},
#    {'article_name': 'Rouse, J.W., Jr.; Haas,R.H.;  Schell, J.A.; Deering, D.W.  - Monitoring the vernal advancement and retrogradation (green wave effect) of natural vegetation\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Schlerf, M.; Atzberger, C.; Hill, J.  - Remote sensing of forest biophysical variables using HyMap imaging spectrometer data\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Schmidt, H.; Karnieli, A. - Sensitivity of vegetation indices to substrate brightness in hyper-arid environment: The Makhtesh Ramon Crater (Israel) case study\n',
#     'article_link': '10.1080/01431160110063779',
#     'article_doi': 'http://dx.doi.org/10.1080/01431160110063779'},
#    {'article_name': 'Serrano, Lydia; Filella, Iolanda; PeÃ±uelas, Josep - Remote Sensing of Biomass and Yield of Winter Wheat under Different Nitrogen Supplies\n',
#     'article_link': '10.2135/cropsci2000.403723x',
#     'article_doi': 'https://www.crops.org/publications/cs/abstracts/40/3/723'},
#    {'article_name': 'Serrano, Lydia; PeÃ±uelas, Josep; Ustin, Susan L. - Remote sensing of nitrogen and lignin in Mediterranean vegetation from AVIRIS data: Decomposing biochemical from structural signals\n',
#     'article_link': '10.1016/s0034-4257(02)00011-1',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425702000111'},
#    {'article_name': 'Smith, RCG; Adams, J; Stephens, DJ; Hick, PT - Forecasting wheat yield in a Mediterranean-type environment from the NOAA satellite\n',
#     'article_link': 'http://dx.doi.org/10.1071/AR9950113',
#     'article_doi': 'http://www.publish.csiro.au/paper/AR9950113'},
#    {'article_name': 'Thenkabail, P. S.; Smith, R. B.; De Pauw, E. - Evaluation of narrowband and broadband vegetation indices for determining optimal hyperspectral wavebands for agricultural crop characterization\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Tucker, C. J.; Elgin Jr, J. H.; McMurtrey Iii, J. E.; Fan, C. J. - Monitoring corn and soybean crop development with hand-held radiometer spectral data\n',
#     'article_link': '10.1016/0034-4257(79)90004-x',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/003442577990004X'},
#    {'article_name': 'Underwood, Emma; Ustin, Susan; DiPietro, Deanne - Mapping nonnative plants using hyperspectral imagery\n',
#     'article_link': '10.1016/s0034-4257(03)00096-8',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425703000968'},
#    {'article_name': 'Vogelmann, J.E.; Rock, B.N.; Moss, D.M.  - Red Edge Spectral Measurements from Sugar Maple Leaves\n',
#     'article_link': '10.1080/01431169308953986',
#     'article_doi': 'http://dx.doi.org/10.1080/01431169308953986'},
#    {'article_name': 'Wang, Fu-min; Huang, Jing-feng; Tang, Yan-lin; Wang, Xiu-zhen - New Vegetation Index and Its Application in Estimating Leaf Area Index of Rice\n',
#     'article_link': '10.1016/s1672-6308(07)60027-4',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S1672630807600274'},
#    {'article_name': 'Wilson, Emily Hoffhine; Sader, Steven A. - Detection of forest harvest type using multiple dates of Landsat TM imagery\n',
#     'article_link': '10.1016/s0034-4257(01)00318-2',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425701003182'},
#    {'article_name': 'Wittich, K. P.; Hansing, O. - AREA-AVERAGED VEGETATIVE COVER FRACTION ESTIMATED FROM SATELLITE DATA\n',
#     'article_link': '10.1007/bf01245391',
#     'article_doi': 'http://apps.webofknowledge.com/InboundService.do?Func=Frame&product=WOS&action=retrieve&SrcApp=EndNote&Init=Yes&SrcAuth=ResearchSoft&mode=FullRecord&UT=A1995RB98100008'},
#    {'article_name': 'Wu, Chaoyang; Niu, Zheng; Tang, Quan; Huang, Wenjiang; Rivard, Benoit; Feng, Jilu - Remote estimation of gross primary production in wheat using chlorophyll-related vegetation indices\n',
#     'article_link': '10.1016/j.agrformet.2008.12.007',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0168192308003560'},
#    {'article_name': 'Wu, Jindong; Wang, Dong; Bauer, Marvin E. - Assessing broadband vegetation indices and QuickBird data in estimating leaf area index of corn and potato canopies\n',
#     'article_link': '10.1016/j.fcr.2007.01.003',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0378429007000160'},
#    {'article_name': 'Yang, Chenghai; Everitt, James H.; Bradford, Joe M.  - Airborne Hyperspectral Imagery and Yield Monitor Data for Mapping Cotton Yield Variability\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Zarco-Tejada P.J.; Miller J.R.        - Land Cover Mapping at BOREAS using red edge spectral parameters from CASI imagery\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Zarco-Tejada P.J.; Sepulcre-CantÃ³, G. - REMOTE SENSING OF VEGETATION BIOPHYSICAL PARAMETERS FOR DETECTING STRESS CONDITION AND LAND COVER CHANGES\n',
#     'article_link': '',
#     'article_doi': ''},
#    {'article_name': 'Zhang, X.; Yan, G.; Li, Q.; Li, Z. L.; Wan, H.; Guo, L. - Evaluating the fraction of vegetation cover based on NDVI spatial scale correction model\n',
#     'article_link': '10.1080/01431160600658107',
#     'article_doi': 'http://apps.webofknowledge.com/InboundService.do?Func=Frame&product=WOS&action=retrieve&SrcApp=EndNote&Init=Yes&SrcAuth=ResearchSoft&mode=FullRecord&UT=000244182300014'},
#    {'article_name': 'Zheng, Guang; Moskal, L. Monika - Retrieving Leaf Area Index (LAI) Using Remote Sensing: Theories, Methods and Sensors\n',
#     'article_link': '',
#     'article_doi': 'http://www.mdpi.com/1424-8220/9/4/2719'}],
#   'satellite_formulas': [{'landsat7': '0.241379310344828'},
#    {'landsat8': '0.241379310344828'},
#    {'aster': '0.241379310344828'},
#    {'sentinel2': '0.241379310344828'},
#    {'EnMAP': '0.241379310344828'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=384',
#   'name': 'Single Band 1510\r',
#   'abbreviation': 'SB1510\r',
#   'formula': '1510nm',
#   'references': [{'article_name': 'Curran, Paul J. - Remote sensing of foliar chemistry\n',
#     'article_link': '10.1016/0034-4257(89)90069-2',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/0034425789900692'},
#    {'article_name': 'Herrmann, I.; Karnieli, A.; Bonfil, D. J.; Cohen, Y.; Alchanatis, V. - SWIR-based spectral indices for assessing nitrogen content in potato fields\n',
#     'article_link': '10.1080/01431160903283892',
#     'article_doi': 'http://dx.doi.org/10.1080/01431160903283892'}],
#   'satellite_formulas': [{'landsat7': 'nan'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'SWIR_49'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=37',
#   'name': 'Kaolinitic\r',
#   'abbreviation': '',
#   'formula': '[2235:2365]/[2145:2185]',
#   'references': [{'article_name': 'Hewson, Rob D.; Cudahy, T. J.; Huntington, J. F. - Geologic and alteration mapping at Mt Fitton, South Australia, using ASTER satellite-borne data\n',
#     'article_link': '10.1109/igarss.2001.976615',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': 'nan'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'nan'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=265',
#   'name': 'Simple Ratio 800/635 Pigment Specific Simple Ratio (Cholophyll b) (PSSRb)\r',
#   'abbreviation': 'SR800/635\r',
#   'formula': '800nm/635nm',
#   'references': [{'article_name': 'Apan, Armando; Held, Alex; Phinn, Stuart; Markley, John - Formulation and assessment of narrow-band vegetation indices from EO-1 hyperion imagery for discriminating sugarcane disease\n',
#     'article_link': '',
#     'article_doi': 'http://eprints.usq.edu.au/8061/'},
#    {'article_name': 'Blackburn, G. A. - Spectral indices for estimating photosynthetic pigment concentrations: A test using senescent tree leaves\n',
#     'article_link': '10.1080/014311698215919',
#     'article_doi': 'http://dx.doi.org/10.1080/014311698215919'},
#    {'article_name': 'GalvÃ£o, LÃªnio Soares; Formaggio, AntÃ´nio Roberto; Tisot, Daniela Arnold - Discrimination of sugarcane varieties in Southeastern Brazil with EO-1 Hyperion data\n',
#     'article_link': '10.1016/j.rse.2004.11.012',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425704003669'},
#    {'article_name': 'Kooistra, L.; Leuven, R. S. E. W.; Wehrens, R.; Nienhuis, P. H.; Buydens, L. M. C. - A comparison of methods to relate grass reflectance to soil metal contamination\n',
#     'article_link': '10.1080/0143116031000080769',
#     'article_doi': 'http://dx.doi.org/10.1080/0143116031000080769'},
#    {'article_name': 'le Maire, G.; Francois, C.; Dufrene, E. - Towards universal broad leaf chlorophyll indices using PROSPECT simulated database and hyperspectral reflectance measurements\n',
#     'article_link': '10.1016/j.rse.2003.09.004',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': 'B4/B3'},
#    {'landsat8': 'nan'},
#    {'aster': 'B3/B2'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'VNIR_67/VNIR_43'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=214',
#   'name': 'Anthocyanin reflectance index\r',
#   'abbreviation': 'ARI\r',
#   'formula': '-1/700nm + 1/550nm',
#   'references': [{'article_name': 'Gitelson, Anatoly A.; Merzlyak, Mark N.; Zur, Y.; Stark, R.; Gritz, U. - Non-destructive and remote sensing techniques for estimation of vegetation status\n',
#     'article_link': '',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': '(-B2 + B8)/(B2*B8)'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': '(-B3 + B5)/(B3*B5)'},
#    {'EnMAP': '(-VNIR_28 + VNIR_53)/(VNIR_28*VNIR_53)'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=270',
#   'name': 'Simple Ratio 1660/680 Disease-Water Stress Index 3\r',
#   'abbreviation': 'DSWI-3\r',
#   'formula': '1660nm/680nm',
#   'references': [{'article_name': 'Apan, Armando; Held, Alex; Phinn, Stuart; Markley, John - Formulation and assessment of narrow-band vegetation indices from EO-1 hyperion imagery for discriminating sugarcane disease\n',
#     'article_link': '',
#     'article_doi': 'http://eprints.usq.edu.au/8061/'}],
#   'satellite_formulas': [{'landsat7': 'B5/B3'},
#    {'landsat8': 'nan'},
#    {'aster': 'B4/B2'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'SWIR_63/VNIR_50'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=307',
#   'name': 'Single Band 680 Blackburn1\r',
#   'abbreviation': 'BB1\r',
#   'formula': '680nm',
#   'references': [{'article_name': 'Blackburn, G. A. - Spectral indices for estimating photosynthetic pigment concentrations: A test using senescent tree leaves\n',
#     'article_link': '10.1080/014311698215919',
#     'article_doi': 'http://dx.doi.org/10.1080/014311698215919'},
#    {'article_name': 'Royo, C.; Aparicio, N.; Villegas, D.; Casadesus, J.; Monneveux, P.; Araus, J. L. - Usefulness of spectral reflectance indices as durum wheat yield predictors under contrasting Mediterranean conditions\n',
#     'article_link': '10.1080/0143116031000150059',
#     'article_doi': 'http://dx.doi.org/10.1080/0143116031000150059'},
#    {'article_name': 'Strachan, Ian B.; Pattey, Elizabeth; Boisvert, Johanne B. - Impact of nitrogen and environmental conditions on corn as detected by hyperspectral reflectance\n',
#     'article_link': '10.1016/s0034-4257(01)00299-1',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': 'B3'},
#    {'landsat8': 'B8'},
#    {'aster': 'B2'},
#    {'sentinel2': 'B4'},
#    {'EnMAP': 'VNIR_50'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=225',
#   'name': 'Normalized Difference Nitrogen Index\r',
#   'abbreviation': 'NDNI\r',
#   'formula': "Can't parse",
#   'references': [{'article_name': 'Herrmann, I.; Karnieli, A.; Bonfil, D. J.; Cohen, Y.; Alchanatis, V. - SWIR-based spectral indices for assessing nitrogen content in potato fields\n',
#     'article_link': '10.1080/01431160903283892',
#     'article_doi': 'http://dx.doi.org/10.1080/01431160903283892'},
#    {'article_name': 'Serrano, Lydia; PeÃ±uelas, Josep; Ustin, Susan L. - Remote sensing of nitrogen and lignin in Mediterranean vegetation from AVIRIS data: Decomposing biochemical from structural signals\n',
#     'article_link': '10.1016/s0034-4257(02)00011-1',
#     'article_doi': 'http://www.sciencedirect.com/science/article/pii/S0034425702000111'}],
#   'satellite_formulas': [{'landsat7': "Can't parse"},
#    {'landsat8': "Can't parse"},
#    {'aster': "Can't parse"},
#    {'sentinel2': "Can't parse"},
#    {'EnMAP': "Can't parse"}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=251',
#   'name': 'Chlorophyll Green\r',
#   'abbreviation': 'Chlgreen\r',
#   'formula': '[540:560]/[760:800]',
#   'references': [{'article_name': 'Gitelson, Anatoly A.; Keydan, Galina P.; Merzlyak, Mark N. - Three-band model for noninvasive estimation of chlorophyll, carotenoids, and anthocyanin contents in higher plant leaves\n',
#     'article_link': '10.1029/2006gl026457',
#     'article_doi': 'http://dx.doi.org/10.1029/2006GL026457'}],
#   'satellite_formulas': [{'landsat7': 'B2/B8'},
#    {'landsat8': 'nan'},
#    {'aster': 'nan'},
#    {'sentinel2': 'nan'},
#    {'EnMAP': 'nan'}]},
#  {'idb_link': 'https://www.indexdatabase.de//db/i-single.php?id=400',
#   'name': 'Normalized Difference 780/550 Green NDVI hyper\r',
#   'abbreviation': 'GNDVIhyper\r',
#   'formula': '(-550nm + 780nm)/(550nm + 780nm)',
#   'references': [{'article_name': 'Gitelson, Anatoly A.; Kaufman, Yoram J.; Merzlyak, Mark N. - Use of a green channel in remote sensing of global vegetation from EOS-MODIS\n',
#     'article_link': '10.1016/s0034-4257(96)00072-7',
#     'article_doi': ''},
#    {'article_name': 'le Maire, G.; Francois, C.; Dufrene, E. - Towards universal broad leaf chlorophyll indices using PROSPECT simulated database and hyperspectral reflectance measurements\n',
#     'article_link': '10.1016/j.rse.2003.09.004',
#     'article_doi': ''}],
#   'satellite_formulas': [{'landsat7': '(-B2 + B4)/(B2 + B4)'},
#    {'landsat8': 'nan'},
#    {'aster': '(-B1 + B3)/(B1 + B3)'},
#    {'sentinel2': '(-B3 + B7)/(B3 + B7)'},
#    {'EnMAP': '(-VNIR_28 + VNIR_64)/(VNIR_28 + VNIR_64)'}]}]

# %% [markdown]
# # Извлечение алиасов

# %%
import pandas as pd

sheets = ["LANDSAT-89 OLITIRS", 
          "Landsat-7 ETM+", 
          "Landsat-45 TM", 
          "Landsat-12345 MSS", 
          "Landsat-123 RBV", 
          "Sentinel-2A MSI", 
          "EMIT",
          "EnMAP"]


df = pd.read_excel("Спутники.xlsx",sheet_name=sheets[0])

for alias, diap in zip(df['Алиас'], df['Диапазон, нм']):
    if str(alias) is not 'nan':
        print(alias)
# Out:
# SR_B1
# SR_B2
# SR_B3
# SR_B4
# SR_B5
# SR_B6
# SR_B7
# SR_B8
# SR_B9
# ST_B10
# ST_B11
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# <>:16: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13816\3598827557.py:16: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
#   if str(alias) is not 'nan':
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
