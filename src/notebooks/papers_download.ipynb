# %%
import pandas as pd
import json

with open("index_data.json", "r", encoding="utf8") as f:
    data = json.load(f)

def get_unique_articles(data):
    seen_dois = set()
    unique_articles = []
    
    for d in data:
        for a in d['references']:
            doi = a['article_link']
            if doi not in seen_dois:
                seen_dois.add(doi)
                unique_articles.append({
                    'doi': doi,
                    'name': a['article_name']
                })
    
    return unique_articles

articles = get_unique_articles(data)

len(articles)
# Out:
# 133

# %%
from pathlib import Path
import os

download_dir = Path(os.getcwd()).parent.parent / "data" / "papers"

# %%
import requests

import time
from urllib.parse import urljoin
import re

def download_from_scihub(doi, article_name, download_dir=download_dir, delay=2):
    """
    Скачивание одной статьи из Sci-Hub по DOI
    
    Args:
        doi: DOI статьи
        article_name: имя для сохранения файла
        download_dir: папка для сохранения
        delay: задержка перед запросом (секунды)
    """
    
    if not os.path.exists(download_dir):
        os.makedirs(download_dir)
    
    # Актуальный домен Sci-Hub
    SCIHUB_BASE = "https://tesble.com/"
    
    # Заголовки чтобы имитировать браузер
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    session = requests.Session()
    session.headers.update(headers)
    
    try:
        print(f"Скачивание: {article_name}")
        print(f"DOI: {doi}")
        
        # Формируем URL для Sci-Hub
        scihub_url = urljoin(SCIHUB_BASE, doi)
        print(f"URL: {scihub_url}")
        
        # Получаем страницу Sci-Hub
        response = session.get(scihub_url, timeout=30)
        response.raise_for_status()
        
        # Ищем прямую ссылку на PDF в HTML
        pdf_url = extract_pdf_url(response.text)
        
        if not pdf_url:
            print(f"✗ Не найдена ссылка на PDF для {article_name}")
            return False, "PDF link not found"
        
        # Скачиваем PDF
        pdf_response = session.get(pdf_url, timeout=30)
        pdf_response.raise_for_status()
        
        # Проверяем что это действительно PDF
        content_type = pdf_response.headers.get('content-type', '')
        if 'application/pdf' not in content_type:
            print(f"✗ Получен не PDF файл для {article_name} (Content-Type: {content_type})")
            return False, "Not a PDF file"
        
        # Создаем безопасное имя файла
        safe_filename = create_safe_filename(article_name) + ".pdf"
        filepath = os.path.join(download_dir, safe_filename)
        
        # Сохраняем файл
        with open(filepath, 'wb') as f:
            f.write(pdf_response.content)
        
        print(f"✓ Успешно скачано: {safe_filename}")
        print(f"Размер файла: {len(pdf_response.content)} байт")
        return True, filepath
        
    except requests.exceptions.RequestException as e:
        print(f"✗ Ошибка сети для {article_name}: {str(e)}")
        return False, f"Network error: {str(e)}"
    except Exception as e:
        print(f"✗ Неожиданная ошибка для {article_name}: {str(e)}")
        return False, f"Unexpected error: {str(e)}"

def extract_pdf_url(html_content):
    """
    Извлекает URL PDF из HTML страницы Sci-Hub
    """
    # Паттерны для поиска ссылки на PDF
    patterns = [
        r'<embed[^>]*src="([^"]*\.pdf[^"]*)"',
        r'<iframe[^>]*src="([^"]*\.pdf[^"]*)"',
        r'<a[^>]*href="([^"]*\.pdf[^"]*)"[^>]*download',
        r'location\.href\s*=\s*["\']([^"\']*\.pdf[^"\']*)["\']'
    ]
    
    for pattern in patterns:
        match = re.search(pattern, html_content, re.IGNORECASE)
        if match:
            pdf_url = match.group(1)
            # Если URL относительный, делаем его абсолютным
            if pdf_url.startswith('//'):
                return 'https:' + pdf_url
            elif pdf_url.startswith('/'):
                return 'https://tesble.com' + pdf_url
            else:
                return pdf_url
    
    return None

def create_safe_filename(filename):
    """
    Создает безопасное имя файла
    """
    # Заменяем недопустимые символы
    safe_name = re.sub(r'[\\/*?:"<>|]', '_', filename)
    safe_name = safe_name.replace('/', '_')
    safe_name = safe_name.replace(':', '_')
    # Убираем лишние пробелы
    safe_name = re.sub(r'\s+', ' ', safe_name).strip()
    # Ограничиваем длину имени
    if len(safe_name) > 100:
        safe_name = safe_name[:100]
    return safe_name

# Функция для скачивания списка статей
def download_articles_list(articles_data, download_dir="papers", delay_between=2):
    """
    Скачивание списка статей
    
    Args:
        articles_data: список словарей [{'doi': '...', 'name': '...'}, ...]
        download_dir: папка для сохранения
        delay_between: задержка между статьями
    """
    success_count = 0
    failed_count = 0
    results = []
    
    for i, article in enumerate(articles_data):
        doi = article.get('doi')
        name = article.get('name')
        
        if not doi or not name:
            print(f"✗ Пропущена статья {i+1}: отсутствует DOI или имя")
            failed_count += 1
            continue
        
        print(f"\n[{i+1}/{len(articles_data)}] ", end="")
        success, result = download_from_scihub(doi, name, download_dir, delay=0)
        
        results.append({
            'article_name': name,
            'doi': doi,
            'success': success,
            'result': result
        })
        
        if success:
            success_count += 1
        else:
            failed_count += 1
        
        # Задержка между статьями (кроме последней)
        if i < len(articles_data) - 1:
            time.sleep(delay_between)
    
    print(f"\n=== ИТОГИ ===")
    print(f"Успешно: {success_count}, Неудачно: {failed_count}")
    return results

# Пример использования
if __name__ == "__main__":
    # Пример для одной статьи
    doi = "10.1007/bf00031911"
    article_name = "Important Research Paper 2024"
    
    success, result = download_from_scihub(doi, article_name)
    
    if success:
        print(f"Статья сохранена как: {result}")
    else:
        print(f"Ошибка: {result}")
    
    # Пример для списка статей
    # articles = [
    #     {'doi': '10.1007/bf00031911', 'name': 'Biology Research Paper'},
    #     {'doi': '10.1038/s41586-021-03375-9', 'name': 'Nature Important Study'},
    #     {'doi': '10.1126/science.abe4473', 'name': 'Science Journal Article'}
    # ]
    
    results = download_articles_list(articles)
# Out:
# Скачивание: Important Research Paper 2024
# DOI: 10.1007/bf00031911
# URL: https://tesble.com/10.1007/bf00031911
# ✓ Успешно скачано: Important Research Paper 2024.pdf
# Размер файла: 389090 байт
# Статья сохранена как: c:\Users\Admin\Desktop\pythonProjects\IndexTable\data\papers\Important Research Paper 2024.pdf
#
# [1/133] Скачивание: Gitelson, Anatoly A.; Merzlyak, Mark N.; Lichtenthaler, Hartmut K. - Detection of Red Edge Position and Chlorophyll Content by Reflectance Measurements Near 700 nm
#
# DOI: 10.1016/s0176-1617(96)80285-9
# URL: https://tesble.com/10.1016/s0176-1617(96)80285-9
# ✓ Успешно скачано: Gitelson, Anatoly A.; Merzlyak, Mark N.; Lichtenthaler, Hartmut K. - Detection of Red Edge Position .pdf
# Размер файла: 958591 байт
#
# [2/133] Скачивание: le Maire, G.; Francois, C.; Dufrene, E. - Towards universal broad leaf chlorophyll indices using PROSPECT simulated database and hyperspectral reflectance measurements
#
# DOI: 10.1016/j.rse.2003.09.004
# URL: https://tesble.com/10.1016/j.rse.2003.09.004
# ✓ Успешно скачано: le Maire, G.; Francois, C.; Dufrene, E. - Towards universal broad leaf chlorophyll indices using PRO.pdf
# Размер файла: 2768311 байт
# ✗ Пропущена статья 3: отсутствует DOI или имя
#
# [4/133] Скачивание: Vogelmann, J.E.; Rock, B.N.; Moss, D.M.  - Red Edge Spectral Measurements from Sugar Maple Leaves
#
# DOI: 10.1080/01431169308953986
# URL: https://tesble.com/10.1080/01431169308953986
# ✓ Успешно скачано: Vogelmann, J.E.; Rock, B.N.; Moss, D.M. - Red Edge Spectral Measurements from Sugar Maple Leaves.pdf
# Размер файла: 485007 байт
#
# [5/133] Скачивание: Gitelson, Anatoly A.; Buschmann, Claus; Lichtenthaler, Hartmut K. - The Chlorophyll Fluorescence Ratio F735/F700 as an Accurate Measure of the Chlorophyll Content in Plants
#
# DOI: 10.1016/s0034-4257(99)00023-1
# URL: https://tesble.com/10.1016/s0034-4257(99)00023-1
# ✓ Успешно скачано: Gitelson, Anatoly A.; Buschmann, Claus; Lichtenthaler, Hartmut K. - The Chlorophyll Fluorescence Rat.pdf
# Размер файла: 368567 байт
#
# [6/133] Скачивание: GalvÃ£o, LÃªnio Soares; Formaggio, AntÃ´nio Roberto; Tisot, Daniela Arnold - Discrimination of sugarcane varieties in Southeastern Brazil with EO-1 Hyperion data
#
# DOI: 10.1016/j.rse.2004.11.012
# URL: https://tesble.com/10.1016/j.rse.2004.11.012
# ✓ Успешно скачано: GalvÃ£o, LÃªnio Soares; Formaggio, AntÃ´nio Roberto; Tisot, Daniela Arnold - Discrimination of sugar.pdf
# Размер файла: 4250063 байт
#
# [7/133] Скачивание: Penuelas, J.; Pinol, J.; Ogaya, R.; Filella, I. - Estimation of plant water concentration by the reflectance Water Index WI (R900/R970)
#
# DOI: 10.1080/014311697217396
# URL: https://tesble.com/10.1080/014311697217396
# ✓ Успешно скачано: Penuelas, J.; Pinol, J.; Ogaya, R.; Filella, I. - Estimation of plant water concentration by the ref.pdf
# Размер файла: 162442 байт
#
# [8/133] Скачивание: Eitel, J. U. H.; Long, D. S.; Gessler, P. E.; Smith, A. M. S. - Using insitu measurements to evaluate the new RapidEyeâ„¢ satellite series for prediction of wheat nitrogen status
#
# DOI: 10.1080/01431160701422213
# URL: https://tesble.com/10.1080/01431160701422213
# ✓ Успешно скачано: Eitel, J. U. H.; Long, D. S.; Gessler, P. E.; Smith, A. M. S. - Using insitu measurements to evaluat.pdf
# Размер файла: 297192 байт
#
# [9/133] Скачивание: Wang, Fu-min; Huang, Jing-feng; Tang, Yan-lin; Wang, Xiu-zhen - New Vegetation Index and Its Application in Estimating Leaf Area Index of Rice
#
# DOI: 10.1016/s1672-6308(07)60027-4
# URL: https://tesble.com/10.1016/s1672-6308(07)60027-4
# ✓ Успешно скачано: Wang, Fu-min; Huang, Jing-feng; Tang, Yan-lin; Wang, Xiu-zhen - New Vegetation Index and Its Applica.pdf
# Размер файла: 105381 байт
#
# [10/133] Скачивание: Aparicio, N.; Villegas, D.; Royo, C.; Casadesus, J.; Araus, J. L. - Effect of sensor view angle on the assessment of agronomic traits by ground level hyper-spectral reflectance measurements in durum wheat under contrasting Mediterranean conditions
#
# DOI: 10.1080/0143116031000116967
# URL: https://tesble.com/10.1080/0143116031000116967
# ✓ Успешно скачано: Aparicio, N.; Villegas, D.; Royo, C.; Casadesus, J.; Araus, J. L. - Effect of sensor view angle on t.pdf
# Размер файла: 325035 байт
#
# [11/133] Скачивание: Gamon, J. A.; Serrano, L.; Surfus, J. S. - The photochemical reflectance index: an optical indicator of photosynthetic radiation use efficiency across species, functional types, and nutrient levels
#
# DOI: 10.1007/s004420050337
# URL: https://tesble.com/10.1007/s004420050337
# ✓ Успешно скачано: Gamon, J. A.; Serrano, L.; Surfus, J. S. - The photochemical reflectance index_ an optical indicator.pdf
# Размер файла: 780372 байт
#
# [12/133] Скачивание: Gamon, J. A.; Surfus, J. S. - Assessing leaf pigment content and activity with a reflectometer
#
# DOI: 10.1046/j.1469-8137.1999.00424.x
# URL: https://tesble.com/10.1046/j.1469-8137.1999.00424.x
# ✓ Успешно скачано: Gamon, J. A.; Surfus, J. S. - Assessing leaf pigment content and activity with a reflectometer.pdf
# Размер файла: 200262 байт
#
# [13/133] Скачивание: Penuelas, Josep; Filella, Iolanda; Gamon, John A. - Assessment of photosynthetic radiation-use efficiency with spectral reflectance
#
# DOI: 10.1111/j.1469-8137.1995.tb03064.x
# URL: https://tesble.com/10.1111/j.1469-8137.1995.tb03064.x
# ✓ Успешно скачано: Penuelas, Josep; Filella, Iolanda; Gamon, John A. - Assessment of photosynthetic radiation-use effic.pdf
# Размер файла: 3196232 байт
#
# [14/133] Скачивание: PeÃ±uelas, J.; Filella, I. - Visible and near-infrared reflectance techniques for diagnosing plant physiological status
#
# DOI: 10.1016/S1360-1385(98)01213-8
# URL: https://tesble.com/10.1016/S1360-1385(98)01213-8
# ✓ Успешно скачано: PeÃ±uelas, J.; Filella, I. - Visible and near-infrared reflectance techniques for diagnosing plant p.pdf
# Размер файла: 330356 байт
#
# [15/133] Скачивание: Royo, C.; Aparicio, N.; Villegas, D.; Casadesus, J.; Monneveux, P.; Araus, J. L. - Usefulness of spectral reflectance indices as durum wheat yield predictors under contrasting Mediterranean conditions
#
# DOI: 10.1080/0143116031000150059
# URL: https://tesble.com/10.1080/0143116031000150059
# ✓ Успешно скачано: Royo, C.; Aparicio, N.; Villegas, D.; Casadesus, J.; Monneveux, P.; Araus, J. L. - Usefulness of spe.pdf
# Размер файла: 185212 байт
#
# [16/133] Скачивание: Sims, Daniel A.; Gamon, John A. - Relationships between leaf pigment content and spectral reflectance across a wide range of species, leaf structures and developmental stages
#
# DOI: 10.1016/s0034-4257(02)00010-x
# URL: https://tesble.com/10.1016/s0034-4257(02)00010-x
# ✓ Успешно скачано: Sims, Daniel A.; Gamon, John A. - Relationships between leaf pigment content and spectral reflectanc.pdf
# Размер файла: 421539 байт
#
# [17/133] Скачивание: Thenot, F.; MÃ©thy, M.; Winkel, T. - The Photochemical Reflectance Index (PRI) as a water-stress index
#
# DOI: 10.1080/01431160210163100
# URL: https://tesble.com/10.1080/01431160210163100
# ✓ Успешно скачано: Thenot, F.; MÃ©thy, M.; Winkel, T. - The Photochemical Reflectance Index (PRI) as a water-stress ind.pdf
# Размер файла: 158162 байт
#
# [18/133] Скачивание: Strachan, Ian B.; Pattey, Elizabeth; Boisvert, Johanne B. - Impact of nitrogen and environmental conditions on corn as detected by hyperspectral reflectance
#
# DOI: 10.1016/s0034-4257(01)00299-1
# URL: https://tesble.com/10.1016/s0034-4257(01)00299-1
# ✓ Успешно скачано: Strachan, Ian B.; Pattey, Elizabeth; Boisvert, Johanne B. - Impact of nitrogen and environmental con.pdf
# Размер файла: 268764 байт
#
# [19/133] Скачивание: Curran, Paul J. - Remote sensing of foliar chemistry
#
# DOI: 10.1016/0034-4257(89)90069-2
# URL: https://tesble.com/10.1016/0034-4257(89)90069-2
# ✓ Успешно скачано: Curran, Paul J. - Remote sensing of foliar chemistry.pdf
# Размер файла: 668898 байт
#
# [20/133] Скачивание: Main, Russell; Cho, Moses Azong; Mathieu, Renaud; Oâ€™Kennedy, Martha M.; Ramoelo, Abel; Koch, Susan - An investigation into robust spectral indices for leaf chlorophyll estimation
#
# DOI: 10.1016/j.isprsjprs.2011.08.001
# URL: https://tesble.com/10.1016/j.isprsjprs.2011.08.001
# ✓ Успешно скачано: Main, Russell; Cho, Moses Azong; Mathieu, Renaud; Oâ€™Kennedy, Martha M.; Ramoelo, Abel; Koch, Susan.pdf
# Размер файла: 625823 байт
#
# [21/133] Скачивание: Nagler, P. L; Daughtry, C. S. T.; Goward, S. N. - Plant Litter and Soil Reflectance
#
# DOI: 10.1016/s0034-4257(99)00082-6
# URL: https://tesble.com/10.1016/s0034-4257(99)00082-6
# ✓ Успешно скачано: Nagler, P. L; Daughtry, C. S. T.; Goward, S. N. - Plant Litter and Soil Reflectance.pdf
# Размер файла: 338499 байт
#
# [22/133] Скачивание: Oppelt, N.; Mauser, W. - Hyperspectral monitoring of physiological parameters of wheat during a vegetation period using AVIS data
#
# DOI: 10.1080/0143116031000115300
# URL: https://tesble.com/10.1080/0143116031000115300
# ✓ Успешно скачано: Oppelt, N.; Mauser, W. - Hyperspectral monitoring of physiological parameters of wheat during a vege.pdf
# Размер файла: 274871 байт
#
# [23/133] Скачивание: Clevers, J. G. P. W. - Application of a weighted infrared-red vegetation index for estimating leaf Area Index by Correcting for Soil Moisture
#
# DOI: 10.1016/0034-4257(89)90076-x
# URL: https://tesble.com/10.1016/0034-4257(89)90076-x
# ✓ Успешно скачано: Clevers, J. G. P. W. - Application of a weighted infrared-red vegetation index for estimating leaf A.pdf
# Размер файла: 781359 байт
#
# [24/133] Скачивание: Clevers, J. G. P. W.; BÃ¼ker, C.; van Leeuwen, H. J. C.; Bouman, B. A. M. - A framework for monitoring crop growth by combining directional and spectral remote sensing information
#
# DOI: 10.1016/0034-4257(94)90042-6
# URL: https://tesble.com/10.1016/0034-4257(94)90042-6
# ✓ Успешно скачано: Clevers, J. G. P. W.; BÃ¼ker, C.; van Leeuwen, H. J. C.; Bouman, B. A. M. - A framework for monitori.pdf
# Размер файла: 934248 байт
#
# [25/133] Скачивание: Dorigo, W. A.; Zurita-Milla, R.; de Wit, A. J. W.; Brazile, J.; Singh, R.; Schaepman, M. E. - A review on reflective remote sensing and data assimilation techniques for enhanced agroecosystem modeling
#
# DOI: 10.1016/j.jag.2006.05.003
# URL: https://tesble.com/10.1016/j.jag.2006.05.003
# ✓ Успешно скачано: Dorigo, W. A.; Zurita-Milla, R.; de Wit, A. J. W.; Brazile, J.; Singh, R.; Schaepman, M. E. - A revi.pdf
# Размер файла: 989613 байт
#
# [26/133] Скачивание: Goel, Narendra S.; Qin, Wenhan - Influences of canopy architecture on relationships between various vegetation indices and LAI and Fpar: A computer simulation
#
# DOI: 10.1080/02757259409532252
# URL: https://tesble.com/10.1080/02757259409532252
# ✓ Успешно скачано: Goel, Narendra S.; Qin, Wenhan - Influences of canopy architecture on relationships between various .pdf
# Размер файла: 1382454 байт
#
# [27/133] Скачивание: Leprieur, C.; Kerr, Y. H.; Pichon, J. M. - Critical assessment of vegetation indices from AVHRR in a semi-arid environment
#
# DOI: 10.1080/01431169608949092
# URL: https://tesble.com/10.1080/01431169608949092
# ✓ Успешно скачано: Leprieur, C.; Kerr, Y. H.; Pichon, J. M. - Critical assessment of vegetation indices from AVHRR in a.pdf
# Размер файла: 550398 байт
#
# [28/133] Скачивание: Qi, J.; Chehbouni, A.; Huete, A. R.; Kerr, Y. H.; Sorooshian, S. - A modified soil adjusted vegetation index
#
# DOI: 10.1016/0034-4257(94)90134-1
# URL: https://tesble.com/10.1016/0034-4257(94)90134-1
# ✓ Успешно скачано: Qi, J.; Chehbouni, A.; Huete, A. R.; Kerr, Y. H.; Sorooshian, S. - A modified soil adjusted vegetati.pdf
# Размер файла: 731624 байт
#
# [29/133] Скачивание: Schmidt, H.; Karnieli, A. - Sensitivity of vegetation indices to substrate brightness in hyper-arid environment: The Makhtesh Ramon Crater (Israel) case study
#
# DOI: 10.1080/01431160110063779
# URL: https://tesble.com/10.1080/01431160110063779
# ✓ Успешно скачано: Schmidt, H.; Karnieli, A. - Sensitivity of vegetation indices to substrate brightness in hyper-arid .pdf
# Размер файла: 1122768 байт
#
# [30/133] Скачивание: Boochs, F.; Kupfer, G.; Dockter, K.; KÃ¼hbauch, W. - Shape of the red edge as vitality indicator for plants
#
# DOI: 10.1080/01431169008955127
# URL: https://tesble.com/10.1080/01431169008955127
# ✓ Успешно скачано: Boochs, F.; Kupfer, G.; Dockter, K.; KÃ¼hbauch, W. - Shape of the red edge as vitality indicator for.pdf
# Размер файла: 438945 байт
#
# [31/133] Скачивание: Bannari, A.; Morin, D.; Bonn, F.; Huete, A. R. - A review of vegetation indices
#
# DOI: 10.1080/02757259509532298
# URL: https://tesble.com/10.1080/02757259509532298
# ✓ Успешно скачано: Bannari, A.; Morin, D.; Bonn, F.; Huete, A. R. - A review of vegetation indices.pdf
# Размер файла: 1686328 байт
#
# [32/133] Скачивание: Gao, Bo-cai - NDWIâ€”A normalized difference water index for remote sensing of vegetation liquid water from space
#
# DOI: 10.1016/s0034-4257(96)00067-3
# URL: https://tesble.com/10.1016/s0034-4257(96)00067-3
# ✓ Успешно скачано: Gao, Bo-cai - NDWIâ€”A normalized difference water index for remote sensing of vegetation liquid wat.pdf
# Размер файла: 936156 байт
#
# [33/133] Скачивание: Gitelson, A. A.; Kaufman, Y. J.; Stark, R.; Rundquist, D. - Novel algorithms for remote estimation of vegetation fraction
#
# DOI: 10.1016/s0034-4257(01)00289-9
# URL: https://tesble.com/10.1016/s0034-4257(01)00289-9
# ✓ Успешно скачано: Gitelson, A. A.; Kaufman, Y. J.; Stark, R.; Rundquist, D. - Novel algorithms for remote estimation o.pdf
# Размер файла: 395894 байт
#
# [34/133] Скачивание: Gitelson, Anatoly A. - Wide Dynamic Range Vegetation Index for Remote Quantification of Biophysical Characteristics of Vegetation
#
# DOI: 10.1078/0176-1617-01176
# URL: https://tesble.com/10.1078/0176-1617-01176
# ✓ Успешно скачано: Gitelson, Anatoly A. - Wide Dynamic Range Vegetation Index for Remote Quantification of Biophysical .pdf
# Размер файла: 153417 байт
#
# [35/133] Скачивание: Gitelson, Anatoly A.; Kaufman, Yoram J.; Merzlyak, Mark N. - Use of a green channel in remote sensing of global vegetation from EOS-MODIS
#
# DOI: 10.1016/s0034-4257(96)00072-7
# URL: https://tesble.com/10.1016/s0034-4257(96)00072-7
# ✓ Успешно скачано: Gitelson, Anatoly A.; Kaufman, Yoram J.; Merzlyak, Mark N. - Use of a green channel in remote sensin.pdf
# Размер файла: 1018269 байт
#
# [36/133] Скачивание: Gitelson, Anatoly A.; ViÃ±a, AndrÃ©s; Arkebauer, Timothy J.; Rundquist, Donald C.; Keydan, Galina: Leavitt, Bryan - Remote estimation of leaf area index and green leaf biomass in maize canopies
#
# DOI: 10.1029/2002gl016450
# URL: https://tesble.com/10.1029/2002gl016450
# ✓ Успешно скачано: Gitelson, Anatoly A.; ViÃ±a, AndrÃ©s; Arkebauer, Timothy J.; Rundquist, Donald C.; Keydan, Galina_ L.pdf
# Размер файла: 155555 байт
#
# [37/133] Скачивание: Huete, A. R.; Liu, H. Q.; Batchily, K.; van Leeuwen, W. - A comparison of vegetation indices over a global set of TM images for EOS-MODIS
#
# DOI: 10.1016/s0034-4257(96)00112-5
# URL: https://tesble.com/10.1016/s0034-4257(96)00112-5
# ✓ Успешно скачано: Huete, A. R.; Liu, H. Q.; Batchily, K.; van Leeuwen, W. - A comparison of vegetation indices over a .pdf
# Размер файла: 1107558 байт
#
# [38/133] Скачивание: Karnieli, A.; Kaufman, Y. J.; Remer, L.; Wald, A. - AFRI - aerosol free vegetation index
#
# DOI: 10.1016/s0034-4257(01)00190-0
# URL: https://tesble.com/10.1016/s0034-4257(01)00190-0
# ✓ Успешно скачано: Karnieli, A.; Kaufman, Y. J.; Remer, L.; Wald, A. - AFRI - aerosol free vegetation index.pdf
# Размер файла: 874795 байт
#
# [39/133] Скачивание: Rondeaux, GeneviÃ¨ve; Steven, Michael; Baret, FrÃ©dÃ©ric - Optimization of soil-adjusted vegetation indices
#
# DOI: 10.1016/0034-4257(95)00186-7
# URL: https://tesble.com/10.1016/0034-4257(95)00186-7
# ✓ Успешно скачано: Rondeaux, GeneviÃ¨ve; Steven, Michael; Baret, FrÃ©dÃ©ric - Optimization of soil-adjusted vegetation .pdf
# Размер файла: 1103511 байт
#
# [40/133] Скачивание: Hewson, Rob D.; Cudahy, T. J.; Huntington, J. F. - Geologic and alteration mapping at Mt Fitton, South Australia, using ASTER satellite-borne data
#
# DOI: 10.1109/igarss.2001.976615
# URL: https://tesble.com/10.1109/igarss.2001.976615
# ✓ Успешно скачано: Hewson, Rob D.; Cudahy, T. J.; Huntington, J. F. - Geologic and alteration mapping at Mt Fitton, Sou.pdf
# Размер файла: 995532 байт
#
# [41/133] Скачивание: Underwood, Emma; Ustin, Susan; DiPietro, Deanne - Mapping nonnative plants using hyperspectral imagery
#
# DOI: 10.1016/s0034-4257(03)00096-8
# URL: https://tesble.com/10.1016/s0034-4257(03)00096-8
# ✓ Успешно скачано: Underwood, Emma; Ustin, Susan; DiPietro, Deanne - Mapping nonnative plants using hyperspectral image.pdf
# Размер файла: 1770290 байт
#
# [42/133] Скачивание: Daughtry, C. S. T.; Walthall, C. L.; Kim, M. S.; de Colstoun, E. Brown; McMurtrey Iii, J. E. - Estimating Corn Leaf Chlorophyll Concentration from Leaf and Canopy Reflectance
#
# DOI: 10.1016/s0034-4257(00)00113-9
# URL: https://tesble.com/10.1016/s0034-4257(00)00113-9
# ✓ Успешно скачано: Daughtry, C. S. T.; Walthall, C. L.; Kim, M. S.; de Colstoun, E. Brown; McMurtrey Iii, J. E. - Estim.pdf
# Размер файла: 514348 байт
#
# [43/133] Скачивание: Haboudane, Driss; Miller, John R.; Pattey, Elizabeth; Zarco-Tejada, Pablo J.; Strachan, Ian B. - Hyperspectral vegetation indices and novel algorithms for predicting green LAI of crop canopies: Modeling and validation in the context of precision agriculture
#
# DOI: 10.1016/j.rse.2003.12.013
# URL: https://tesble.com/10.1016/j.rse.2003.12.013
# ✓ Успешно скачано: Haboudane, Driss; Miller, John R.; Pattey, Elizabeth; Zarco-Tejada, Pablo J.; Strachan, Ian B. - Hyp.pdf
# Размер файла: 1167502 байт
#
# [44/133] Скачивание: Haboudane, Driss; Miller, John R.; Tremblay, Nicolas; Zarco-Tejada, Pablo J.; Dextraze, Louise - Integrated narrow-band vegetation indices for prediction of crop chlorophyll content for application to precision agriculture
#
# DOI: 10.1016/s0034-4257(02)00018-4
# URL: https://tesble.com/10.1016/s0034-4257(02)00018-4
# ✓ Успешно скачано: Haboudane, Driss; Miller, John R.; Tremblay, Nicolas; Zarco-Tejada, Pablo J.; Dextraze, Louise - Int.pdf
# Размер файла: 471087 байт
#
# [45/133] Скачивание: Herrmann, I.; Karnieli, A.; Bonfil, D. J.; Cohen, Y.; Alchanatis, V. - SWIR-based spectral indices for assessing nitrogen content in potato fields
#
# DOI: 10.1080/01431160903283892
# URL: https://tesble.com/10.1080/01431160903283892
# ✓ Успешно скачано: Herrmann, I.; Karnieli, A.; Bonfil, D. J.; Cohen, Y.; Alchanatis, V. - SWIR-based spectral indices f.pdf
# Размер файла: 330469 байт
#
# [46/133] Скачивание: Wu, Chaoyang; Niu, Zheng; Tang, Quan; Huang, Wenjiang - Estimating chlorophyll content from hyperspectral vegetation indices: Modeling and validation
#
# DOI: 10.1016/j.agrformet.2008.03.005
# URL: https://tesble.com/10.1016/j.agrformet.2008.03.005
# ✓ Успешно скачано: Wu, Chaoyang; Niu, Zheng; Tang, Quan; Huang, Wenjiang - Estimating chlorophyll content from hyperspe.pdf
# Размер файла: 2313239 байт
#
# [47/133] Скачивание: Blackburn, G. A. - Spectral indices for estimating photosynthetic pigment concentrations: A test using senescent tree leaves
#
# DOI: 10.1080/014311698215919
# URL: https://tesble.com/10.1080/014311698215919
# ✓ Успешно скачано: Blackburn, G. A. - Spectral indices for estimating photosynthetic pigment concentrations_ A test usi.pdf
# Размер файла: 297601 байт
#
# [48/133] Скачивание: Lichtenthaler, Hartmut K. - Vegetation Stress: an Introduction to the Stress Concept in Plants
#
# DOI: 10.1016/s0176-1617(96)80287-2
# URL: https://tesble.com/10.1016/s0176-1617(96)80287-2
# ✓ Успешно скачано: Lichtenthaler, Hartmut K. - Vegetation Stress_ an Introduction to the Stress Concept in Plants.pdf
# Размер файла: 1699736 байт
#
# [49/133] Скачивание: Gitelson, Anatoly; Merzlyak, Mark N. - Quantitative estimation of chlorophyll-a using reflectance spectra: Experiments with autumn chestnut and maple leaves
#
# DOI: 10.1016/1011-1344(93)06963-4
# URL: https://tesble.com/10.1016/1011-1344(93)06963-4
# ✓ Успешно скачано: Gitelson, Anatoly; Merzlyak, Mark N. - Quantitative estimation of chlorophyll-a using reflectance sp.pdf
# Размер файла: 575558 байт
#
# [50/133] Скачивание: Richardson, Andrew D.; Duigan, Shane P.; Berlyn, Graeme P. - An evaluation of noninvasive methods to estimate foliar chlorophyll content
#
# DOI: 10.1046/j.0028-646X.2001.00289.x
# URL: https://tesble.com/10.1046/j.0028-646X.2001.00289.x
# ✓ Успешно скачано: Richardson, Andrew D.; Duigan, Shane P.; Berlyn, Graeme P. - An evaluation of noninvasive methods to.pdf
# Размер файла: 694438 байт
#
# [51/133] Скачивание: Heiskanen, J. - Estimating aboveground tree biomass and leaf area index in a mountain birch forest using ASTER satellite data
#
# DOI: 10.1080/01431160500353858
# URL: https://tesble.com/10.1080/01431160500353858
# ✓ Успешно скачано: Heiskanen, J. - Estimating aboveground tree biomass and leaf area index in a mountain birch forest u.pdf
# Размер файла: 443297 байт
#
# [52/133] Скачивание: Cibula, W. G.; Zetka, E. F.; Rickman, D. L. - Response of thematic mapper bands to plant water stress
#
# DOI: 10.1080/01431169208904236
# URL: https://tesble.com/10.1080/01431169208904236
# ✓ Успешно скачано: Cibula, W. G.; Zetka, E. F.; Rickman, D. L. - Response of thematic mapper bands to plant water stres.pdf
# Размер файла: 337357 байт
#
# [53/133] Скачивание: Wilson, Emily Hoffhine; Sader, Steven A. - Detection of forest harvest type using multiple dates of Landsat TM imagery
#
# DOI: 10.1016/s0034-4257(01)00318-2
# URL: https://tesble.com/10.1016/s0034-4257(01)00318-2
# ✓ Успешно скачано: Wilson, Emily Hoffhine; Sader, Steven A. - Detection of forest harvest type using multiple dates of .pdf
# Размер файла: 163546 байт
#
# [54/133] Скачивание: Datt, Bisun - Remote Sensing of Water Content in Eucalyptus Leaves
#
# DOI: http://dx.doi.org/10.1071/BT98042
# URL: http://dx.doi.org/10.1071/BT98042
# ✗ Ошибка сети для Datt, Bisun - Remote Sensing of Water Content in Eucalyptus Leaves
# : 403 Client Error: Forbidden for url: https://connectsci.au/bt/article/47/6/909/5228/Remote-Sensing-of-Water-Content-in-Eucalyptus
#
# [55/133] Скачивание: Datt, Bisun - Remote Sensing of Chlorophyll a, Chlorophyll b, Chlorophyll a+b, and Total Carotenoid Content in Eucalyptus Leaves
#
# DOI: 10.1016/s0034-4257(98)00046-7
# URL: https://tesble.com/10.1016/s0034-4257(98)00046-7
# ✓ Успешно скачано: Datt, Bisun - Remote Sensing of Chlorophyll a, Chlorophyll b, Chlorophyll a+b, and Total Carotenoid .pdf
# Размер файла: 323823 байт
#
# [56/133] Скачивание: Broge, N. H.; Leblanc, E. - Comparing prediction power and stability of broadband and hyperspectral vegetation indices for estimation of green leaf area index and canopy chlorophyll density
#
# DOI: 10.1016/s0034-4257(00)00197-8
# URL: https://tesble.com/10.1016/s0034-4257(00)00197-8
# ✓ Успешно скачано: Broge, N. H.; Leblanc, E. - Comparing prediction power and stability of broadband and hyperspectral .pdf
# Размер файла: 758943 байт
#
# [57/133] Скачивание: Serrano, Lydia; PeÃ±uelas, Josep; Ustin, Susan L. - Remote sensing of nitrogen and lignin in Mediterranean vegetation from AVIRIS data: Decomposing biochemical from structural signals
#
# DOI: 10.1016/s0034-4257(02)00011-1
# URL: https://tesble.com/10.1016/s0034-4257(02)00011-1
# ✓ Успешно скачано: Serrano, Lydia; PeÃ±uelas, Josep; Ustin, Susan L. - Remote sensing of nitrogen and lignin in Mediter.pdf
# Размер файла: 163612 байт
#
# [58/133] Скачивание: Ahamed, T.; Tian, L.; Zhang, Y.; Ting, K. C. - A review of remote sensing methods for biomass feedstock production
#
# DOI: 10.1016/j.biombioe.2011.02.028
# URL: https://tesble.com/10.1016/j.biombioe.2011.02.028
# ✓ Успешно скачано: Ahamed, T.; Tian, L.; Zhang, Y.; Ting, K. C. - A review of remote sensing methods for biomass feedst.pdf
# Размер файла: 1194773 байт
#
# [59/133] Скачивание: Hancock, D. W.; Dougherty, C. T. - Relationships between blue- and red-based vegetation indices and leaf area and yield of alfalfa
#
# DOI: 10.2135/cropsci2007.01.0031
# URL: https://tesble.com/10.2135/cropsci2007.01.0031
# ✓ Успешно скачано: Hancock, D. W.; Dougherty, C. T. - Relationships between blue- and red-based vegetation indices and .pdf
# Размер файла: 1702893 байт
#
# [60/133] Скачивание: Agriculture
#
# DOI:
# URL: https://tesble.com/
# ✗ Не найдена ссылка на PDF для Agriculture
#
#
# [61/133] Скачивание: Carter, Gregory A. - Ratios of leaf reflectances in narrow wavebands as indicators of plant stress
#
# DOI: 10.1080/01431169408954109
# URL: https://tesble.com/10.1080/01431169408954109
# ✓ Успешно скачано: Carter, Gregory A. - Ratios of leaf reflectances in narrow wavebands as indicators of plant stress.pdf
# Размер файла: 267035 байт
#
# [62/133] Скачивание: Carter, Gregory A.; Cibula, William G.; Miller, Richard L. - Narrow-band Reflectance Imagery Compared with ThermalImagery for Early Detection of Plant Stress
#
# DOI: 10.1016/s0176-1617(96)80070-8
# URL: https://tesble.com/10.1016/s0176-1617(96)80070-8
# ✓ Успешно скачано: Carter, Gregory A.; Cibula, William G.; Miller, Richard L. - Narrow-band Reflectance Imagery Compare.pdf
# Размер файла: 1033075 байт
#
# [63/133] Скачивание: Cloutis, E. A.; Connery, D. R.; Major, D. J.; Dover, F. J. - Airborne multi-spectral monitoring of agricultural crop status: effect of time of year, crop type and crop condition parameter
#
# DOI: 10.1080/01431169608949094
# URL: https://tesble.com/10.1080/01431169608949094
# ✓ Успешно скачано: Cloutis, E. A.; Connery, D. R.; Major, D. J.; Dover, F. J. - Airborne multi-spectral monitoring of a.pdf
# Размер файла: 1988260 байт
#
# [64/133] Скачивание: Gitelson, A. A.; Merzlyak, M. N. - Remote estimation of chlorophyll content in higher plant leaves
#
# DOI: 10.1080/014311697217558
# URL: https://tesble.com/10.1080/014311697217558
# ✓ Успешно скачано: Gitelson, A. A.; Merzlyak, M. N. - Remote estimation of chlorophyll content in higher plant leaves.pdf
# Размер файла: 179147 байт
#
# [65/133] Скачивание: Merzlyak, Mark N.; Gitelson, Anatoly A.; Chivkunova, Olga B.; Rakitin, Victor Y. U. - Non-destructive optical detection of pigment changes during leaf senescence and fruit ripening
#
# DOI: 10.1034/j.1399-3054.1999.106119.x
# URL: https://tesble.com/10.1034/j.1399-3054.1999.106119.x
# ✓ Успешно скачано: Merzlyak, Mark N.; Gitelson, Anatoly A.; Chivkunova, Olga B.; Rakitin, Victor Y. U. - Non-destructiv.pdf
# Размер файла: 481159 байт
#
# [66/133] Скачивание: Maccioni, Andrea; Agati, Giovanni; Mazzinghi, Piero - New vegetation indices for remote measurement of chlorophylls based on leaf directional reflectance spectra
#
# DOI: 10.1016/s1011-1344(01)00145-2
# URL: https://tesble.com/10.1016/s1011-1344(01)00145-2
# ✓ Успешно скачано: Maccioni, Andrea; Agati, Giovanni; Mazzinghi, Piero - New vegetation indices for remote measurement .pdf
# Размер файла: 359532 байт
#
# [67/133] Скачивание: Herrmann, I.; Pimstein, A.; Karnieli, A.; Cohen, Y.; Alchanatis, V.; Bonfil, D. J. - LAI assessment of wheat and potato crops by VENÂµS and Sentinel-2 bands
#
# DOI: 10.1016/j.rse.2011.04.018
# URL: https://tesble.com/10.1016/j.rse.2011.04.018
# ✓ Успешно скачано: Herrmann, I.; Pimstein, A.; Karnieli, A.; Cohen, Y.; Alchanatis, V.; Bonfil, D. J. - LAI assessment .pdf
# Размер файла: 983212 байт
#
# [68/133] Скачивание: Kooistra, L.; Leuven, R. S. E. W.; Wehrens, R.; Nienhuis, P. H.; Buydens, L. M. C. - A comparison of methods to relate grass reflectance to soil metal contamination
#
# DOI: 10.1080/0143116031000080769
# URL: https://tesble.com/10.1080/0143116031000080769
# ✓ Успешно скачано: Kooistra, L.; Leuven, R. S. E. W.; Wehrens, R.; Nienhuis, P. H.; Buydens, L. M. C. - A comparison of.pdf
# Размер файла: 954766 байт
#
# [69/133] Скачивание: Gamon, J. A.; PeÃ±uelas, J.; Field, C. B. - A narrow-waveband spectral index that tracks diurnal changes in photosynthetic efficiency
#
# DOI: 10.1016/0034-4257(92)90059-s
# URL: https://tesble.com/10.1016/0034-4257(92)90059-s
# ✓ Успешно скачано: Gamon, J. A.; PeÃ±uelas, J.; Field, C. B. - A narrow-waveband spectral index that tracks diurnal cha.pdf
# Размер файла: 856374 байт
#
# [70/133] Скачивание: Nichol, Caroline J.; Huemmrich, Karl F.; Black, T. Andrew; Jarvis, Paul G.; Walthall, Charles L.; Grace, John; Hall, Forrest G. - Remote sensing of photosynthetic-light-use efficiency of boreal forest
#
# DOI: 10.1016/s0168-1923(99)00167-7
# URL: https://tesble.com/10.1016/s0168-1923(99)00167-7
# ✓ Успешно скачано: Nichol, Caroline J.; Huemmrich, Karl F.; Black, T. Andrew; Jarvis, Paul G.; Walthall, Charles L.; Gr.pdf
# Размер файла: 204552 байт
#
# [71/133] Скачивание: Penuelas, J.; Llusia, J.; Pinol, J.; Filella, I. - Photochemical reflectance index and leaf photosynthetic radiation-use-efficiency assessment in Mediterranean trees
#
# DOI: 10.1080/014311697217387
# URL: https://tesble.com/10.1080/014311697217387
# ✓ Успешно скачано: Penuelas, J.; Llusia, J.; Pinol, J.; Filella, I. - Photochemical reflectance index and leaf photosyn.pdf
# Размер файла: 158992 байт
#
# [72/133] Скачивание: Kaufman, Y. J.;Tanre, D. - Atmospherically resistant vegetation index (ARVI) for EOS-MODIS
#
# DOI: 10.1109/36.134076
# URL: https://tesble.com/10.1109/36.134076
# ✓ Успешно скачано: Kaufman, Y. J.;Tanre, D. - Atmospherically resistant vegetation index (ARVI) for EOS-MODIS.pdf
# Размер файла: 1074411 байт
#
# [73/133] Скачивание: Clevers, J. G. P. W.; De Jong, S. M.; Epema, G. F.; Van Der Meer, F. D.; Bakker, W. H.; Skidmore, A. K.; Scholte, K. H. - Derivation of the red edge index using the MERIS standard band setting
#
# DOI: 10.1080/01431160110104647
# URL: https://tesble.com/10.1080/01431160110104647
# ✓ Успешно скачано: Clevers, J. G. P. W.; De Jong, S. M.; Epema, G. F.; Van Der Meer, F. D.; Bakker, W. H.; Skidmore, A..pdf
# Размер файла: 304655 байт
#
# [74/133] Скачивание: Dash, J.; Curran, P. J. - The MERIS terrestrial chlorophyll index
#
# DOI: 10.1080/0143116042000274015
# URL: https://tesble.com/10.1080/0143116042000274015
# ✓ Успешно скачано: Dash, J.; Curran, P. J. - The MERIS terrestrial chlorophyll index.pdf
# Размер файла: 520334 байт
#
# [75/133] Скачивание: Kooistra, L.; Salas, E. A. L.; Clevers, J. G. P. W.; Wehrens, R.; Leuven, R. S. E. W.; Nienhuis, P. H.; Buydens, L. M. C. - Exploring field vegetation reflectance as an indicator of soil contamination in river floodplains
#
# DOI: 10.1016/s0269-7491(03)00266-5
# URL: https://tesble.com/10.1016/s0269-7491(03)00266-5
# ✓ Успешно скачано: Kooistra, L.; Salas, E. A. L.; Clevers, J. G. P. W.; Wehrens, R.; Leuven, R. S. E. W.; Nienhuis, P. .pdf
# Размер файла: 402999 байт
#
# [76/133] Скачивание: Shibayama, Michio; Salli, Arto; HÃ¤me, Tuomas; Iso-Iivari, Lasse; Heino, Saini; Alanen, Marjaana; Morinaga, Shinsuke; Inoue, Yoshio; Akiyama, Tsuyoshi - Detecting Phenophases of Subarctic Shrub Canopies by Using Automated Reflectance Measurements
#
# DOI: 10.1016/s0034-4257(98)00082-0
# URL: https://tesble.com/10.1016/s0034-4257(98)00082-0
# ✓ Успешно скачано: Shibayama, Michio; Salli, Arto; HÃ¤me, Tuomas; Iso-Iivari, Lasse; Heino, Saini; Alanen, Marjaana; Mo.pdf
# Размер файла: 895900 байт
#
# [77/133] Скачивание: PeÃ±uelas, J.; Gamon, J. A.; Fredeen, A. L.; Merino, J.; Field, C. B. - Reflectance indices associated with physiological changes in nitrogen- and water-limited sunflower leaves
#
# DOI: 10.1016/0034-4257(94)90136-8
# URL: https://tesble.com/10.1016/0034-4257(94)90136-8
# ✓ Успешно скачано: PeÃ±uelas, J.; Gamon, J. A.; Fredeen, A. L.; Merino, J.; Field, C. B. - Reflectance indices associat.pdf
# Размер файла: 1085239 байт
#
# [78/133] Скачивание: Bausch, Walter C. - Soil background effects on reflectance-based crop coefficients for corn
#
# DOI: 10.1016/0034-4257(93)90096-G
# URL: https://tesble.com/10.1016/0034-4257(93)90096-G
# ✓ Успешно скачано: Bausch, Walter C. - Soil background effects on reflectance-based crop coefficients for corn.pdf
# Размер файла: 910197 байт
#
# [79/133] Скачивание: Tucker, C. J.; Elgin Jr, J. H.; McMurtrey Iii, J. E.; Fan, C. J. - Monitoring corn and soybean crop development with hand-held radiometer spectral data
#
# DOI: 10.1016/0034-4257(79)90004-x
# URL: https://tesble.com/10.1016/0034-4257(79)90004-x
# ✓ Успешно скачано: Tucker, C. J.; Elgin Jr, J. H.; McMurtrey Iii, J. E.; Fan, C. J. - Monitoring corn and soybean crop .pdf
# Размер файла: 705154 байт
#
# [80/133] Скачивание: Hunt Jr, E. Raymond; Rock, Barrett N. - Detection of changes in leaf water content using Near- and Middle-Infrared reflectances
#
# DOI: 10.1016/0034-4257(89)90046-1
# URL: https://tesble.com/10.1016/0034-4257(89)90046-1
# ✓ Успешно скачано: Hunt Jr, E. Raymond; Rock, Barrett N. - Detection of changes in leaf water content using Near- and M.pdf
# Размер файла: 995369 байт
#
# [81/133] Скачивание: Hunt Jr, Raymond E.; Rock, Barrett N.; Nobel, Park S. - Measurement of leaf relative water content by infrared reflectance
#
# DOI: 10.1016/0034-4257(87)90094-0
# URL: https://tesble.com/10.1016/0034-4257(87)90094-0
# ✓ Успешно скачано: Hunt Jr, Raymond E.; Rock, Barrett N.; Nobel, Park S. - Measurement of leaf relative water content b.pdf
# Размер файла: 483735 байт
#
# [82/133] Скачивание: Xie, H.; Tian, Y. Q.; Granillo, J. A.; Keller, G. R. - Suitable remote sensing method and data for mapping and measuring active crop fields
#
# DOI: 10.1080/01431160600702673
# URL: https://tesble.com/10.1080/01431160600702673
# ✓ Успешно скачано: Xie, H.; Tian, Y. Q.; Granillo, J. A.; Keller, G. R. - Suitable remote sensing method and data for m.pdf
# Размер файла: 908090 байт
#
# [83/133] Скачивание: Gobron, N.; Pinty, B.; Verstraete, M. M.; Widlowski, J. L. - Advanced vegetation indices optimized for up-coming sensors: Design, performance, and applications
#
# DOI: 10.1109/36.885197
# URL: https://tesble.com/10.1109/36.885197
# ✓ Успешно скачано: Gobron, N.; Pinty, B.; Verstraete, M. M.; Widlowski, J. L. - Advanced vegetation indices optimized f.pdf
# Размер файла: 789773 байт
#
# [84/133] Скачивание: Ceccato, Pietro; Flasse, StÃ©phane; Tarantola, Stefano; Jacquemoud, StÃ©phane; GrÃ©goire, Jean-Marie - Detecting vegetation leaf water content using reflectance in the optical domain
#
# DOI: 10.1016/s0034-4257(01)00191-2
# URL: https://tesble.com/10.1016/s0034-4257(01)00191-2
# ✓ Успешно скачано: Ceccato, Pietro; Flasse, StÃ©phane; Tarantola, Stefano; Jacquemoud, StÃ©phane; GrÃ©goire, Jean-Marie.pdf
# Размер файла: 277401 байт
#
# [85/133] Скачивание: Pinty, B.; Verstraete, M. M. - GEMI: a non-linear index to monitor global vegetation from satellites
#
# DOI: 10.1007/bf00031911
# URL: https://tesble.com/10.1007/bf00031911
# ✓ Успешно скачано: Pinty, B.; Verstraete, M. M. - GEMI_ a non-linear index to monitor global vegetation from satellites.pdf
# Размер файла: 389090 байт
#
# [86/133] Скачивание: Huete, A. R. - A soil-adjusted vegetation index (SAVI)
#
# DOI: 10.1016/0034-4257(88)90106-x
# URL: https://tesble.com/10.1016/0034-4257(88)90106-x
# ✓ Успешно скачано: Huete, A. R. - A soil-adjusted vegetation index (SAVI).pdf
# Размер файла: 949734 байт
#
# [87/133] Скачивание: Major, D. J.; Baret, F.; Guyot, G. - A ratio vegetation index adjusted for soil brightness
#
# DOI: 10.1080/01431169008955053
# URL: https://tesble.com/10.1080/01431169008955053
# ✓ Успешно скачано: Major, D. J.; Baret, F.; Guyot, G. - A ratio vegetation index adjusted for soil brightness.pdf
# Размер файла: 504209 байт
#
# [88/133] Скачивание: Wu, Jindong; Wang, Dong; Bauer, Marvin E. - Assessing broadband vegetation indices and QuickBird data in estimating leaf area index of corn and potato canopies
#
# DOI: 10.1016/j.fcr.2007.01.003
# URL: https://tesble.com/10.1016/j.fcr.2007.01.003
# ✓ Успешно скачано: Wu, Jindong; Wang, Dong; Bauer, Marvin E. - Assessing broadband vegetation indices and QuickBird dat.pdf
# Размер файла: 678530 байт
#
# [89/133] Скачивание: Serrano, Lydia; Ustin, Susan L.; Roberts, Dar A.; Gamon, John A.; PeÃ±uelas, Josep - Deriving Water Content of Chaparral Vegetation from AVIRIS Data
#
# DOI: 10.1016/s0034-4257(00)00147-4
# URL: https://tesble.com/10.1016/s0034-4257(00)00147-4
# ✓ Успешно скачано: Serrano, Lydia; Ustin, Susan L.; Roberts, Dar A.; Gamon, John A.; PeÃ±uelas, Josep - Deriving Water .pdf
# Размер файла: 896534 байт
#
# [90/133] Скачивание: Wu, Chaoyang; Niu, Zheng; Tang, Quan; Huang, Wenjiang; Rivard, Benoit; Feng, Jilu - Remote estimation of gross primary production in wheat using chlorophyll-related vegetation indices
#
# DOI: 10.1016/j.agrformet.2008.12.007
# URL: https://tesble.com/10.1016/j.agrformet.2008.12.007
# ✓ Успешно скачано: Wu, Chaoyang; Niu, Zheng; Tang, Quan; Huang, Wenjiang; Rivard, Benoit; Feng, Jilu - Remote estimatio.pdf
# Размер файла: 879882 байт
#
# [91/133] Скачивание: Gitelson, Anatoly A.; Keydan, Galina P.; Merzlyak, Mark N. - Three-band model for noninvasive estimation of chlorophyll, carotenoids, and anthocyanin contents in higher plant leaves
#
# DOI: 10.1029/2006gl026457
# URL: https://tesble.com/10.1029/2006gl026457
# ✓ Успешно скачано: Gitelson, Anatoly A.; Keydan, Galina P.; Merzlyak, Mark N. - Three-band model for noninvasive estima.pdf
# Размер файла: 247602 байт
#
# [92/133] Скачивание: Smith, RCG; Adams, J; Stephens, DJ; Hick, PT - Forecasting wheat yield in a Mediterranean-type environment from the NOAA satellite
#
# DOI: http://dx.doi.org/10.1071/AR9950113
# URL: http://dx.doi.org/10.1071/AR9950113
# ✗ Ошибка сети для Smith, RCG; Adams, J; Stephens, DJ; Hick, PT - Forecasting wheat yield in a Mediterranean-type environment from the NOAA satellite
# : 403 Client Error: Forbidden for url: https://connectsci.au/cp/article/46/1/113/32746/Forecasting-wheat-yield-in-a-Mediterranean-type
#
# [93/133] Скачивание: Clarke, T. R.; Moran, M. S.; Barnes, E. M.; Pinter, P. J., Jr.; Qi, J. - Planar domain indices: a method for measuring a quality of a single component in two-component pixels
#
# DOI: 10.1109/igarss.2001.976818
# URL: https://tesble.com/10.1109/igarss.2001.976818
# ✓ Успешно скачано: Clarke, T. R.; Moran, M. S.; Barnes, E. M.; Pinter, P. J., Jr.; Qi, J. - Planar domain indices_ a me.pdf
# Размер файла: 559021 байт
#
# [94/133] Скачивание: Ceccato, Pietro; Gobron, Nadine; Flasse, StÃ©phane; Pinty, Bernard; Tarantola, Stefano - Designing a spectral index to estimate vegetation water content from remote sensing data: Part 1: Theoretical approach
#
# DOI: 10.1016/s0034-4257(02)00037-8
# URL: https://tesble.com/10.1016/s0034-4257(02)00037-8
# ✓ Успешно скачано: Ceccato, Pietro; Gobron, Nadine; Flasse, StÃ©phane; Pinty, Bernard; Tarantola, Stefano - Designing a.pdf
# Размер файла: 349882 байт
#
# [95/133] Скачивание: Penuelas, J.; Filella, I.; Biel, C.; Serrano, L.; Save, R. - The reflectance at the 950â€“970 nm region as an indicator of plant water status
#
# DOI: 10.1080/01431169308954010
# URL: https://tesble.com/10.1080/01431169308954010
# ✓ Успешно скачано: Penuelas, J.; Filella, I.; Biel, C.; Serrano, L.; Save, R. - The reflectance at the 950â€“970 nm reg.pdf
# Размер файла: 677769 байт
#
# [96/133] Скачивание: Buschmann, C.; Nagel, E. - In vivo spectroscopy and internal optics of leaves as basis for remote sensing of vegetation
#
# DOI: 10.1080/01431169308904370
# URL: https://tesble.com/10.1080/01431169308904370
# ✓ Успешно скачано: Buschmann, C.; Nagel, E. - In vivo spectroscopy and internal optics of leaves as basis for remote se.pdf
# Размер файла: 527444 байт
#
# [97/133] Скачивание: PeÃ±uelas, Josep; Gamon, John A.; Griffin, Kevin L.; Field, Christopher B. - Assessing community type, plant biomass, pigment composition, and photosynthetic efficiency of aquatic vegetation from spectral reflectance
#
# DOI: 10.1016/0034-4257(93)90088-f
# URL: https://tesble.com/10.1016/0034-4257(93)90088-f
# ✓ Успешно скачано: PeÃ±uelas, Josep; Gamon, John A.; Griffin, Kevin L.; Field, Christopher B. - Assessing community typ.pdf
# Размер файла: 867321 байт
#
# [98/133] Скачивание: Zarco-Tejada, P. J.; Rueda, C. A.; Ustin, S. L. - Water content estimation in vegetation with MODIS reflectance data and model inversion methods
#
# DOI: 10.1016/s0034-4257(02)00197-9
# URL: https://tesble.com/10.1016/s0034-4257(02)00197-9
# ✓ Успешно скачано: Zarco-Tejada, P. J.; Rueda, C. A.; Ustin, S. L. - Water content estimation in vegetation with MODIS .pdf
# Размер файла: 1480454 байт
#
# [99/133] Скачивание: Crist, Eric P.; Cicone, Richard C. - A Physically-Based Transformation of Thematic Mapper Data---The TM Tasseled Cap
#
# DOI: 10.1109/tgrs.1984.350619
# URL: https://tesble.com/10.1109/tgrs.1984.350619
# ✓ Успешно скачано: Crist, Eric P.; Cicone, Richard C. - A Physically-Based Transformation of Thematic Mapper Data---The.pdf
# Размер файла: 2619599 байт
#
# [100/133] Скачивание: Ferencz, C.; Bognar, P.; Lichtenberger, J.; Hamar, D.; Tarscai, G.; Timar, G.; Molnar, G.; Pasztor, S.; Steinbach, P.; Szekely, B.; Ferencz, O. E.; Ferencz-Arkos, I. - Crop yield estimation by satellite remote sensing
#
# DOI: 10.1080/01431160410001698870
# URL: https://tesble.com/10.1080/01431160410001698870
# ✓ Успешно скачано: Ferencz, C.; Bognar, P.; Lichtenberger, J.; Hamar, D.; Tarscai, G.; Timar, G.; Molnar, G.; Pasztor, .pdf
# Размер файла: 1035278 байт
#
# [101/133] Скачивание: Friedl, M. A.; Schimel, D. S.; Michaelsen, J.; Davis, F. W.; Walker, H. - Estimating grassland biomass and leaf area index using ground and satellite data
#
# DOI: 10.1080/01431169408954174
# URL: https://tesble.com/10.1080/01431169408954174
# ✓ Успешно скачано: Friedl, M. A.; Schimel, D. S.; Michaelsen, J.; Davis, F. W.; Walker, H. - Estimating grassland bioma.pdf
# Размер файла: 769482 байт
#
# [102/133] Скачивание: Lee, W. S.; Alchanatis, V.; Yang, C.; Hirafuji, M.; Moshou, D.; Li, C. - Sensing technologies for precision specialty crop production
#
# DOI: 10.1016/j.compag.2010.08.005
# URL: https://tesble.com/10.1016/j.compag.2010.08.005
# ✓ Успешно скачано: Lee, W. S.; Alchanatis, V.; Yang, C.; Hirafuji, M.; Moshou, D.; Li, C. - Sensing technologies for pr.pdf
# Размер файла: 1724760 байт
#
# [103/133] Скачивание: Zarco-Tejada, P. J.; Pushnik, J. C.; Dobrowski, S.; Ustin, S. L. - Steady-state chlorophyll a fluorescence detection from canopy derivative reflectance and double-peak red-edge effects
#
# DOI: 10.1016/s0034-4257(02)00113-x
# URL: https://tesble.com/10.1016/s0034-4257(02)00113-x
# ✓ Успешно скачано: Zarco-Tejada, P. J.; Pushnik, J. C.; Dobrowski, S.; Ustin, S. L. - Steady-state chlorophyll a fluore.pdf
# Размер файла: 975659 байт
#
# [104/133] Скачивание: Pu, R.; Ge, S.; Kelly, N. M.; Gong, P. - Spectral absorption features as indicators of water status in coast live oak ( Quercus agrifolia ) leaves
#
# DOI: 10.1080/01431160210155965
# URL: https://tesble.com/10.1080/01431160210155965
# ✓ Успешно скачано: Pu, R.; Ge, S.; Kelly, N. M.; Gong, P. - Spectral absorption features as indicators of water status .pdf
# Размер файла: 261782 байт
#
# [105/133] Скачивание: Perry Jr, Charles R.; Lautenschlager, Lyle F. - Functional equivalence of spectral vegetation indices
#
# DOI: 10.1016/0034-4257(84)90013-0
# URL: https://tesble.com/10.1016/0034-4257(84)90013-0
# ✓ Успешно скачано: Perry Jr, Charles R.; Lautenschlager, Lyle F. - Functional equivalence of spectral vegetation indice.pdf
# Размер файла: 989136 байт
#
# [106/133] Скачивание: le Maire, Guerric; FranÃ§ois, Christophe; Soudani, Kamel; Berveiller, Daniel; Pontailler, Jean-Yves; BrÃ©da, Nathalie; Genet, HÃ©lÃ¨ne; Davi, Hendrik; DufrÃªne, Eric - Calibration and validation of hyperspectral indices for the estimation of broadleaved forest leaf chlorophyll content, leaf mass per area, leaf area index and leaf canopy biomass
#
# DOI: 10.1016/j.rse.2008.06.005
# URL: https://tesble.com/10.1016/j.rse.2008.06.005
# ✓ Успешно скачано: le Maire, Guerric; FranÃ§ois, Christophe; Soudani, Kamel; Berveiller, Daniel; Pontailler, Jean-Yves;.pdf
# Размер файла: 2298979 байт
#
# [107/133] Скачивание: Huete, A. R.; Jackson, R. D. - Soil and atmosphere influences on the spectra of partial canopies
#
# DOI: 10.1016/0034-4257(88)90043-0
# URL: https://tesble.com/10.1016/0034-4257(88)90043-0
# ✓ Успешно скачано: Huete, A. R.; Jackson, R. D. - Soil and atmosphere influences on the spectra of partial canopies.pdf
# Размер файла: 1093016 байт
#
# [108/133] Скачивание: Choubey, V. K.; Choubey, R. - Spectral reflectance, growth and chlorophyll relationships for rice crop in a semi-arid region of India
#
# DOI: 10.1023/a:1008056400348
# URL: https://tesble.com/10.1023/a:1008056400348
# ✓ Успешно скачано: Choubey, V. K.; Choubey, R. - Spectral reflectance, growth and chlorophyll relationships for rice cr.pdf
# Размер файла: 103508 байт
#
# [109/133] Скачивание: Malthus, Tim J.; Andrieu, Bruno; Danson, F. Mark; Jaggard, Keith W.; Steven, Michael D. - Candidate high spectral resolution infrared indices for crop cover
#
# DOI: 10.1016/0034-4257(93)90095-f
# URL: https://tesble.com/10.1016/0034-4257(93)90095-f
# ✓ Успешно скачано: Malthus, Tim J.; Andrieu, Bruno; Danson, F. Mark; Jaggard, Keith W.; Steven, Michael D. - Candidate .pdf
# Размер файла: 818168 байт
#
# [110/133] Скачивание: Serrano, Lydia; Filella, Iolanda; PeÃ±uelas, Josep - Remote Sensing of Biomass and Yield of Winter Wheat under Different Nitrogen Supplies
#
# DOI: 10.2135/cropsci2000.403723x
# URL: https://tesble.com/10.2135/cropsci2000.403723x
# ✓ Успешно скачано: Serrano, Lydia; Filella, Iolanda; PeÃ±uelas, Josep - Remote Sensing of Biomass and Yield of Winter W.pdf
# Размер файла: 240554 байт
#
# [111/133] Скачивание: Fensholt, Rasmus; Sandholt, Inge - Derivation of a shortwave infrared water stress index from MODIS near- and shortwave infrared data in a semiarid environment
#
# DOI: 10.1016/j.rse.2003.07.002
# URL: https://tesble.com/10.1016/j.rse.2003.07.002
# ✓ Успешно скачано: Fensholt, Rasmus; Sandholt, Inge - Derivation of a shortwave infrared water stress index from MODIS .pdf
# Размер файла: 946919 байт
#
# [112/133] Скачивание: Crippen, Robert E. - Calculating the vegetation index faster
#
# DOI: 10.1016/0034-4257(90)90085-z
# URL: https://tesble.com/10.1016/0034-4257(90)90085-z
# ✓ Успешно скачано: Crippen, Robert E. - Calculating the vegetation index faster.pdf
# Размер файла: 207455 байт
#
# [113/133] Скачивание: Bastiaanssen, Wim G. M.; Molden, David J.; Makin, Ian W. - Remote sensing for irrigated agriculture: examples from research and possible applications
#
# DOI: 10.1016/s0378-3774(00)00080-9
# URL: https://tesble.com/10.1016/s0378-3774(00)00080-9
# ✓ Успешно скачано: Bastiaanssen, Wim G. M.; Molden, David J.; Makin, Ian W. - Remote sensing for irrigated agriculture_.pdf
# Размер файла: 191383 байт
#
# [114/133] Скачивание: Glenn, E. P.; Nagler, P. L.; Huete, A. R. - Vegetation Index Methods for Estimating Evapotranspiration by Remote Sensing
#
# DOI: 10.1007/s10712-010-9102-2
# URL: https://tesble.com/10.1007/s10712-010-9102-2
# ✓ Успешно скачано: Glenn, E. P.; Nagler, P. L.; Huete, A. R. - Vegetation Index Methods for Estimating Evapotranspirati.pdf
# Размер файла: 531041 байт
#
# [115/133] Скачивание: Huete, A. R.; Hua, G.; Qi, J.; Chehbouni, A.; van Leeuwen, W. J. D. - Normalization of multidirectional red and NIR reflectances with the SAVI
#
# DOI: 10.1016/0034-4257(92)90074-t
# URL: https://tesble.com/10.1016/0034-4257(92)90074-t
# ✓ Успешно скачано: Huete, A. R.; Hua, G.; Qi, J.; Chehbouni, A.; van Leeuwen, W. J. D. - Normalization of multidirectio.pdf
# Размер файла: 916612 байт
#
# [116/133] Скачивание: Barnes, J. D.; Balaguer, L.; Manrique, E.; Elvira, S.; Davison, A. W. - A Reappraisal of the Use of Dmso for the Extraction and Determination of Chlorophylls-a and Chlorophylls-B in Lichens and Higher-Plants
#
# DOI: 10.1016/0098-8472(92)90034-y
# URL: https://tesble.com/10.1016/0098-8472(92)90034-y
# ✓ Успешно скачано: Barnes, J. D.; Balaguer, L.; Manrique, E.; Elvira, S.; Davison, A. W. - A Reappraisal of the Use of .pdf
# Размер файла: 1224270 байт
#
# [117/133] Скачивание: Vincini M., Frazzi, E. and D' Alessio, P.  - A broad-band leaf chlorophyll vegetation index at the canopy scale
#
# DOI: 10.1007/s11119-008-9075-z
# URL: https://tesble.com/10.1007/s11119-008-9075-z
# ✓ Успешно скачано: Vincini M., Frazzi, E. and D' Alessio, P. - A broad-band leaf chlorophyll vegetation index at the ca.pdf
# Размер файла: 428779 байт
#
# [118/133] Скачивание: Glenn, Edward; Huete, Alfredo; Nagler, Pamela; Nelson, Stephen - Review - Relationship Between Remotely-sensed Vegetation Indices, Canopy Attributes and Plant Physiological Processes: What Vegetation Indices Can and Cannot Tell Us About the Landscape
#
# DOI: doi:10.3390/s8042136
# URL: doi:10.3390/s8042136
# ✗ Ошибка сети для Glenn, Edward; Huete, Alfredo; Nagler, Pamela; Nelson, Stephen - Review - Relationship Between Remotely-sensed Vegetation Indices, Canopy Attributes and Plant Physiological Processes: What Vegetation Indices Can and Cannot Tell Us About the Landscape
# : No connection adapters were found for 'doi:10.3390/s8042136'
#
# [119/133] Скачивание: Huete, A.; Didan, K.; Miura, T.; Rodriguez, E. P.; Gao, X.; Ferreira, L. G. - Overview of the radiometric and biophysical performance of the MODIS vegetation indices
#
# DOI: 10.1016/s0034-4257(02)00096-2
# URL: https://tesble.com/10.1016/s0034-4257(02)00096-2
# ✓ Успешно скачано: Huete, A.; Didan, K.; Miura, T.; Rodriguez, E. P.; Gao, X.; Ferreira, L. G. - Overview of the radiom.pdf
# Размер файла: 1375925 байт
#
# [120/133] Скачивание: Nagler, Pamela L.; Scott, Russell L.; Westenburg, Craig; Cleverly, James R.; Glenn, Edward P.; Huete, Alfredo R. - Evapotranspiration on western U.S. rivers estimated using the Enhanced Vegetation Index from MODIS and data from eddy covariance and Bowen ratio flux towers
#
# DOI: 10.1016/j.rse.2005.05.011
# URL: https://tesble.com/10.1016/j.rse.2005.05.011
# ✓ Успешно скачано: Nagler, Pamela L.; Scott, Russell L.; Westenburg, Craig; Cleverly, James R.; Glenn, Edward P.; Huete.pdf
# Размер файла: 477426 байт
#
# [121/133] Скачивание: Roujean, Jean-Louis; Breon, FranÃ§ois-Marie - Estimating PAR absorbed by vegetation from bidirectional reflectance measurements
#
# DOI: 10.1016/0034-4257(94)00114-3
# URL: https://tesble.com/10.1016/0034-4257(94)00114-3
# ✓ Успешно скачано: Roujean, Jean-Louis; Breon, FranÃ§ois-Marie - Estimating PAR absorbed by vegetation from bidirection.pdf
# Размер файла: 1056021 байт
#
# [122/133] Скачивание: Moulin, S.; Bondeau, A.; Delecolle, R. - Combining agricultural crop models and satellite observations: from field to regional scales
#
# DOI: 10.1080/014311698215586
# URL: https://tesble.com/10.1080/014311698215586
# ✓ Успешно скачано: Moulin, S.; Bondeau, A.; Delecolle, R. - Combining agricultural crop models and satellite observatio.pdf
# Размер файла: 305390 байт
#
# [123/133] Скачивание: Baret, F.; Guyot, G.; Major, D. J. - Crop biomass evaluation using radiometric measurements
#
# DOI: 10.1016/0031-8663(89)90001-x
# URL: https://tesble.com/10.1016/0031-8663(89)90001-x
# ✓ Успешно скачано: Baret, F.; Guyot, G.; Major, D. J. - Crop biomass evaluation using radiometric measurements.pdf
# Размер файла: 890189 байт
#
# [124/133] Скачивание: Becker-Reshef, I.; Vermote, E.; Lindeman, M.; Justice, C. - A generalized regression-based model for forecasting winter wheat yields in Kansas and Ukraine using MODIS data
#
# DOI: 10.1016/j.rse.2010.01.010
# URL: https://tesble.com/10.1016/j.rse.2010.01.010
# ✓ Успешно скачано: Becker-Reshef, I.; Vermote, E.; Lindeman, M.; Justice, C. - A generalized regression-based model for.pdf
# Размер файла: 2467935 байт
#
# [125/133] Скачивание: Brown, Daniel G.; Duh, Jiunn-Der; Drzyzga, Scott A. - Estimating Error in an Analysis of Forest Fragmentation Change Using North American Landscape Characterization (NALC) Data
#
# DOI: 10.1016/s0034-4257(99)00070-x
# URL: https://tesble.com/10.1016/s0034-4257(99)00070-x
# ✓ Успешно скачано: Brown, Daniel G.; Duh, Jiunn-Der; Drzyzga, Scott A. - Estimating Error in an Analysis of Forest Frag.pdf
# Размер файла: 856746 байт
#
# [126/133] Скачивание: Brown, R. B.; Noble, S. D. - Site-specific weed management: sensing requirements - what do we need to see?
#
# DOI: 10.1614/ws-04-068r1
# URL: https://tesble.com/10.1614/ws-04-068r1
# ✓ Успешно скачано: Brown, R. B.; Noble, S. D. - Site-specific weed management_ sensing requirements - what do we need t.pdf
# Размер файла: 130396 байт
#
# [127/133] Скачивание: Dang, Y. P.; Pringle, M. J.; Schmidt, M.; Dalal, R. C.; Apan, A. - Identifying the spatial variability of soil constraints using multi-year remote sensing
#
# DOI: 10.1016/j.fcr.2011.05.021
# URL: https://tesble.com/10.1016/j.fcr.2011.05.021
# ✓ Успешно скачано: Dang, Y. P.; Pringle, M. J.; Schmidt, M.; Dalal, R. C.; Apan, A. - Identifying the spatial variabili.pdf
# Размер файла: 836130 байт
#
# [128/133] Скачивание: Garson, D. Caraux; Lacaze, B. - Monitoring Leaf Area Index of Mediterranean oak woodlands: Comparison of remotely-sensed estimates with simulations from an ecological process-based model
#
# DOI: 10.1080/0143116021000024267
# URL: https://tesble.com/10.1080/0143116021000024267
# ✓ Успешно скачано: Garson, D. Caraux; Lacaze, B. - Monitoring Leaf Area Index of Mediterranean oak woodlands_ Compariso.pdf
# Размер файла: 442658 байт
#
# [129/133] Скачивание: Hu, S.; Mo, X. G. - Interpreting spatial heterogeneity of crop yield with a process model and remote sensing
#
# DOI: 10.1016/j.ecolmodel.2010.11.011
# URL: https://tesble.com/10.1016/j.ecolmodel.2010.11.011
# ✓ Успешно скачано: Hu, S.; Mo, X. G. - Interpreting spatial heterogeneity of crop yield with a process model and remote.pdf
# Размер файла: 2672920 байт
#
# [130/133] Скачивание: Moran, M. S.; Inoue, Y.; Barnes, E. M. - Opportunities and limitations for image-based remote sensing in precision crop management
#
# DOI: 10.1016/s0034-4257(97)00045-x
# URL: https://tesble.com/10.1016/s0034-4257(97)00045-x
# ✓ Успешно скачано: Moran, M. S.; Inoue, Y.; Barnes, E. M. - Opportunities and limitations for image-based remote sensin.pdf
# Размер файла: 4456106 байт
#
# [131/133] Скачивание: Ricotta, Carlo; Avena, Giancarlo; De Palma, Alessandra - Mapping and monitoring net primary productivity with AVHRR NDVI time-series: statistical equivalence of cumulative vegetation indices
#
# DOI: 10.1016/s0924-2716(99)00028-3
# URL: https://tesble.com/10.1016/s0924-2716(99)00028-3
# ✓ Успешно скачано: Ricotta, Carlo; Avena, Giancarlo; De Palma, Alessandra - Mapping and monitoring net primary producti.pdf
# Размер файла: 104469 байт
#
# [132/133] Скачивание: Wittich, K. P.; Hansing, O. - AREA-AVERAGED VEGETATIVE COVER FRACTION ESTIMATED FROM SATELLITE DATA
#
# DOI: 10.1007/bf01245391
# URL: https://tesble.com/10.1007/bf01245391
# ✓ Успешно скачано: Wittich, K. P.; Hansing, O. - AREA-AVERAGED VEGETATIVE COVER FRACTION ESTIMATED FROM SATELLITE DATA.pdf
# Размер файла: 747398 байт
#
# [133/133] Скачивание: Zhang, X.; Yan, G.; Li, Q.; Li, Z. L.; Wan, H.; Guo, L. - Evaluating the fraction of vegetation cover based on NDVI spatial scale correction model
#
# DOI: 10.1080/01431160600658107
# URL: https://tesble.com/10.1080/01431160600658107
# ✓ Успешно скачано: Zhang, X.; Yan, G.; Li, Q.; Li, Z. L.; Wan, H.; Guo, L. - Evaluating the fraction of vegetation cove.pdf
# Размер файла: 431737 байт
#
# === ИТОГИ ===
# Успешно: 128, Неудачно: 5
